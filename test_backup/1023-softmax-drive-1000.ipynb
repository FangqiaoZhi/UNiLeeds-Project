# %%
import code.model as model

from PIL import Image
import matplotlib.pyplot as plt

import itertools
import numpy as np
import time
import torch
from torch import nn, optim
import torch.nn.functional as F
import torchvision.transforms as tmf
import pandas as pd

# Dataloader prepare
from code.data_reader import get_loaders_and_datasets
from code.config import DATASET_NAME, epoch_round, validation_round
# Get value which is static in one running 
from code.static import lp_method, device, net
if lp_method:
    print('use LP method')
else:
    print('use softmax')

print('device:', device)
print('dataset name:', DATASET_NAME)
print(f'Validate per {validation_round} round')
print(f'Limitation: {epoch_round} round.')

# Get data loaders
_loaders, _datasets = get_loaders_and_datasets()
train_loader, validate_loader, test_loader = _loaders
dataset_train, dataset_validate, dataset_test = _datasets
# Out:
# use softmax
# device: cuda:0
# dataset name: DRIVE
# Validate per 5 round
# Limitation: 1000 round.

# %%
from code.trainer import train

# Do the training
max_run_round = epoch_round
statsrec, cmtensor = train(max_run_round, train_loader, validate_loader)
# Out:
# epoch 0 time Sat Oct 23 12:26:11 2021
# epoch 1 time Sat Oct 23 12:26:19 2021
# epoch 2 time Sat Oct 23 12:26:25 2021
# epoch 3 time Sat Oct 23 12:26:32 2021
# epoch 4 time Sat Oct 23 12:26:39 2021
# Epoch:4 TrainLoss: 0.20904 ValidationLoss:  0.17683, Accuracy: 0.94321, Precision: 0.78372, Recall: 0.57427 F1: 0.66285, +: 268950, -: 4274857, False+: 199382, False-: 74219
# epoch 5 time Sat Oct 23 12:26:50 2021
# epoch 6 time Sat Oct 23 12:26:56 2021
# epoch 7 time Sat Oct 23 12:27:03 2021
# epoch 8 time Sat Oct 23 12:27:10 2021
# epoch 9 time Sat Oct 23 12:27:17 2021
# Epoch:9 TrainLoss: 0.16131 ValidationLoss:  0.14187, Accuracy: 0.95053, Precision: 0.75748, Recall: 0.72247 F1: 0.73956, +: 338358, -: 4240743, False+: 129974, False-: 108333
# epoch 10 time Sat Oct 23 12:27:28 2021
# epoch 11 time Sat Oct 23 12:27:35 2021
# epoch 12 time Sat Oct 23 12:27:42 2021
# epoch 13 time Sat Oct 23 12:27:49 2021
# epoch 14 time Sat Oct 23 12:27:56 2021
# Epoch:14 TrainLoss: 0.15466 ValidationLoss:  0.13727, Accuracy: 0.95306, Precision: 0.79760, Recall: 0.69305 F1: 0.74166, +: 324578, -: 4266709, False+: 143754, False-: 82367
# epoch 15 time Sat Oct 23 12:28:06 2021
# epoch 16 time Sat Oct 23 12:28:13 2021
# epoch 17 time Sat Oct 23 12:28:20 2021
# epoch 18 time Sat Oct 23 12:28:27 2021
# epoch 19 time Sat Oct 23 12:28:34 2021
# Epoch:19 TrainLoss: 0.14211 ValidationLoss:  0.12720, Accuracy: 0.95317, Precision: 0.79121, Recall: 0.70405 F1: 0.74509, +: 329727, -: 4262065, False+: 138605, False-: 87011
# epoch 20 time Sat Oct 23 12:28:45 2021
# epoch 21 time Sat Oct 23 12:28:52 2021
# epoch 22 time Sat Oct 23 12:28:59 2021
# epoch 23 time Sat Oct 23 12:29:06 2021
# epoch 24 time Sat Oct 23 12:29:12 2021
# Epoch:24 TrainLoss: 0.13985 ValidationLoss:  0.11789, Accuracy: 0.95689, Precision: 0.80627, Recall: 0.73257 F1: 0.76766, +: 343087, -: 4266641, False+: 125245, False-: 82435
# epoch 25 time Sat Oct 23 12:29:23 2021
# epoch 26 time Sat Oct 23 12:29:30 2021
# epoch 27 time Sat Oct 23 12:29:37 2021
# epoch 28 time Sat Oct 23 12:29:44 2021
# epoch 29 time Sat Oct 23 12:29:51 2021
# Epoch:29 TrainLoss: 0.13153 ValidationLoss:  0.11297, Accuracy: 0.95818, Precision: 0.80770, Recall: 0.74787 F1: 0.77663, +: 350253, -: 4265684, False+: 118079, False-: 83392
# epoch 30 time Sat Oct 23 12:30:01 2021
# epoch 31 time Sat Oct 23 12:30:08 2021
# epoch 32 time Sat Oct 23 12:30:15 2021
# epoch 33 time Sat Oct 23 12:30:22 2021
# epoch 34 time Sat Oct 23 12:30:29 2021
# Epoch:34 TrainLoss: 0.13888 ValidationLoss:  0.11558, Accuracy: 0.95691, Precision: 0.82247, Recall: 0.71005 F1: 0.76214, +: 332541, -: 4277297, False+: 135791, False-: 71779
# epoch 35 time Sat Oct 23 12:30:40 2021
# epoch 36 time Sat Oct 23 12:30:47 2021
# epoch 37 time Sat Oct 23 12:30:53 2021
# epoch 38 time Sat Oct 23 12:31:00 2021
# epoch 39 time Sat Oct 23 12:31:07 2021
# Epoch:39 TrainLoss: 0.13364 ValidationLoss:  0.11132, Accuracy: 0.95830, Precision: 0.86713, Recall: 0.67437 F1: 0.75870, +: 315829, -: 4300683, False+: 152503, False-: 48393
# epoch 40 time Sat Oct 23 12:31:18 2021
# epoch 41 time Sat Oct 23 12:31:25 2021
# epoch 42 time Sat Oct 23 12:31:32 2021
# epoch 43 time Sat Oct 23 12:31:39 2021
# epoch 44 time Sat Oct 23 12:31:46 2021
# Epoch:44 TrainLoss: 0.13278 ValidationLoss:  0.11004, Accuracy: 0.95850, Precision: 0.83821, Recall: 0.71015 F1: 0.76888, +: 332584, -: 4284883, False+: 135748, False-: 64193
# epoch 45 time Sat Oct 23 12:31:57 2021
# epoch 46 time Sat Oct 23 12:32:04 2021
# epoch 47 time Sat Oct 23 12:32:10 2021
# epoch 48 time Sat Oct 23 12:32:17 2021
# epoch 49 time Sat Oct 23 12:32:24 2021
# Epoch:49 TrainLoss: 0.13449 ValidationLoss:  0.10812, Accuracy: 0.95867, Precision: 0.82703, Recall: 0.72695 F1: 0.77377, +: 340456, -: 4277869, False+: 127876, False-: 71207
# epoch 50 time Sat Oct 23 12:32:35 2021
# epoch 51 time Sat Oct 23 12:32:42 2021
# epoch 52 time Sat Oct 23 12:32:49 2021
# epoch 53 time Sat Oct 23 12:32:56 2021
# epoch 54 time Sat Oct 23 12:33:03 2021
# Epoch:54 TrainLoss: 0.13132 ValidationLoss:  0.10408, Accuracy: 0.96067, Precision: 0.83647, Recall: 0.74009 F1: 0.78534, +: 346608, -: 4281315, False+: 121724, False-: 67761
# epoch 55 time Sat Oct 23 12:33:13 2021
# epoch 56 time Sat Oct 23 12:33:20 2021
# epoch 57 time Sat Oct 23 12:33:27 2021
# epoch 58 time Sat Oct 23 12:33:34 2021
# epoch 59 time Sat Oct 23 12:33:41 2021
# Epoch:59 TrainLoss: 0.12478 ValidationLoss:  0.10419, Accuracy: 0.96005, Precision: 0.79768, Recall: 0.78926 F1: 0.79345, +: 369635, -: 4255325, False+: 98697, False-: 93751
# epoch 60 time Sat Oct 23 12:33:52 2021
# epoch 61 time Sat Oct 23 12:33:59 2021
# epoch 62 time Sat Oct 23 12:34:06 2021
# epoch 63 time Sat Oct 23 12:34:13 2021
# epoch 64 time Sat Oct 23 12:34:20 2021
# Epoch:64 TrainLoss: 0.12714 ValidationLoss:  0.10881, Accuracy: 0.95851, Precision: 0.81235, Recall: 0.74543 F1: 0.77745, +: 349109, -: 4268435, False+: 119223, False-: 80641
# epoch 65 time Sat Oct 23 12:34:30 2021
# epoch 66 time Sat Oct 23 12:34:37 2021
# epoch 67 time Sat Oct 23 12:34:44 2021
# epoch 68 time Sat Oct 23 12:34:51 2021
# epoch 69 time Sat Oct 23 12:34:58 2021
# Epoch:69 TrainLoss: 0.12915 ValidationLoss:  0.10546, Accuracy: 0.96013, Precision: 0.82719, Recall: 0.74567 F1: 0.78432, +: 349221, -: 4276118, False+: 119111, False-: 72958
# epoch 70 time Sat Oct 23 12:35:09 2021
# epoch 71 time Sat Oct 23 12:35:16 2021
# epoch 72 time Sat Oct 23 12:35:23 2021
# epoch 73 time Sat Oct 23 12:35:30 2021
# epoch 74 time Sat Oct 23 12:35:37 2021
# Epoch:74 TrainLoss: 0.12493 ValidationLoss:  0.10079, Accuracy: 0.96092, Precision: 0.83443, Recall: 0.74600 F1: 0.78774, +: 349374, -: 4279752, False+: 118958, False-: 69324
# epoch 75 time Sat Oct 23 12:35:47 2021
# epoch 76 time Sat Oct 23 12:35:54 2021
# epoch 77 time Sat Oct 23 12:36:01 2021
# epoch 78 time Sat Oct 23 12:36:08 2021
# epoch 79 time Sat Oct 23 12:36:15 2021
# Epoch:79 TrainLoss: 0.12052 ValidationLoss:  0.10454, Accuracy: 0.95975, Precision: 0.88367, Recall: 0.67477 F1: 0.76522, +: 316015, -: 4307476, False+: 152317, False-: 41600
# epoch 80 time Sat Oct 23 12:36:26 2021
# epoch 81 time Sat Oct 23 12:36:33 2021
# epoch 82 time Sat Oct 23 12:36:40 2021
# epoch 83 time Sat Oct 23 12:36:47 2021
# epoch 84 time Sat Oct 23 12:36:54 2021
# Epoch:84 TrainLoss: 0.11738 ValidationLoss:  0.10516, Accuracy: 0.95891, Precision: 0.86063, Recall: 0.68894 F1: 0.76527, +: 322654, -: 4296825, False+: 145678, False-: 52251
# epoch 85 time Sat Oct 23 12:37:04 2021
# epoch 86 time Sat Oct 23 12:37:11 2021
# epoch 87 time Sat Oct 23 12:37:18 2021
# epoch 88 time Sat Oct 23 12:37:25 2021
# epoch 89 time Sat Oct 23 12:37:32 2021
# Epoch:89 TrainLoss: 0.12036 ValidationLoss:  0.10046, Accuracy: 0.96070, Precision: 0.85063, Recall: 0.72267 F1: 0.78144, +: 338448, -: 4289643, False+: 129884, False-: 59433
# epoch 90 time Sat Oct 23 12:37:43 2021
# epoch 91 time Sat Oct 23 12:37:50 2021
# epoch 92 time Sat Oct 23 12:37:57 2021
# epoch 93 time Sat Oct 23 12:38:04 2021
# epoch 94 time Sat Oct 23 12:38:10 2021
# Epoch:94 TrainLoss: 0.12029 ValidationLoss:  0.10485, Accuracy: 0.95932, Precision: 0.80072, Recall: 0.77424 F1: 0.78726, +: 362600, -: 4258836, False+: 105732, False-: 90240
# epoch 95 time Sat Oct 23 12:38:21 2021
# epoch 96 time Sat Oct 23 12:38:28 2021
# epoch 97 time Sat Oct 23 12:38:35 2021
# epoch 98 time Sat Oct 23 12:38:42 2021
# epoch 99 time Sat Oct 23 12:38:49 2021
# Epoch:99 TrainLoss: 0.11886 ValidationLoss:  0.09959, Accuracy: 0.96115, Precision: 0.83568, Recall: 0.74729 F1: 0.78901, +: 349978, -: 4280259, False+: 118354, False-: 68817
# epoch 100 time Sat Oct 23 12:38:59 2021
# epoch 101 time Sat Oct 23 12:39:06 2021
# epoch 102 time Sat Oct 23 12:39:13 2021
# epoch 103 time Sat Oct 23 12:39:20 2021
# epoch 104 time Sat Oct 23 12:39:27 2021
# Epoch:104 TrainLoss: 0.12212 ValidationLoss:  0.10033, Accuracy: 0.96079, Precision: 0.84874, Recall: 0.72609 F1: 0.78264, +: 340050, -: 4288474, False+: 128282, False-: 60602
# epoch 105 time Sat Oct 23 12:39:38 2021
# epoch 106 time Sat Oct 23 12:39:45 2021
# epoch 107 time Sat Oct 23 12:39:51 2021
# epoch 108 time Sat Oct 23 12:39:58 2021
# epoch 109 time Sat Oct 23 12:40:05 2021
# Epoch:109 TrainLoss: 0.11959 ValidationLoss:  0.09894, Accuracy: 0.96192, Precision: 0.81015, Recall: 0.79443 F1: 0.80221, +: 372058, -: 4261887, False+: 96274, False-: 87189
# epoch 110 time Sat Oct 23 12:40:16 2021
# epoch 111 time Sat Oct 23 12:40:23 2021
# epoch 112 time Sat Oct 23 12:40:30 2021
# epoch 113 time Sat Oct 23 12:40:37 2021
# epoch 114 time Sat Oct 23 12:40:44 2021
# Epoch:114 TrainLoss: 0.12070 ValidationLoss:  0.09565, Accuracy: 0.96293, Precision: 0.82839, Recall: 0.78034 F1: 0.80365, +: 365458, -: 4273366, False+: 102874, False-: 75710
# epoch 115 time Sat Oct 23 12:40:54 2021
# epoch 116 time Sat Oct 23 12:41:01 2021
# epoch 117 time Sat Oct 23 12:41:08 2021
# epoch 118 time Sat Oct 23 12:41:15 2021
# epoch 119 time Sat Oct 23 12:41:22 2021
# Epoch:119 TrainLoss: 0.11825 ValidationLoss:  0.09919, Accuracy: 0.96130, Precision: 0.81390, Recall: 0.78030 F1: 0.79675, +: 365441, -: 4265515, False+: 102891, False-: 83561
# epoch 120 time Sat Oct 23 12:41:33 2021
# epoch 121 time Sat Oct 23 12:41:40 2021
# epoch 122 time Sat Oct 23 12:41:47 2021
# epoch 123 time Sat Oct 23 12:41:54 2021
# epoch 124 time Sat Oct 23 12:42:01 2021
# Epoch:124 TrainLoss: 0.12042 ValidationLoss:  0.09493, Accuracy: 0.96245, Precision: 0.84400, Recall: 0.75286 F1: 0.79583, +: 352590, -: 4283907, False+: 115742, False-: 65169
# epoch 125 time Sat Oct 23 12:42:11 2021
# epoch 126 time Sat Oct 23 12:42:18 2021
# epoch 127 time Sat Oct 23 12:42:25 2021
# epoch 128 time Sat Oct 23 12:42:32 2021
# epoch 129 time Sat Oct 23 12:42:39 2021
# Epoch:129 TrainLoss: 0.11478 ValidationLoss:  0.09794, Accuracy: 0.96177, Precision: 0.83254, Recall: 0.75951 F1: 0.79435, +: 355701, -: 4277531, False+: 112631, False-: 71545
# epoch 130 time Sat Oct 23 12:42:50 2021
# epoch 131 time Sat Oct 23 12:42:57 2021
# epoch 132 time Sat Oct 23 12:43:04 2021
# epoch 133 time Sat Oct 23 12:43:11 2021
# epoch 134 time Sat Oct 23 12:43:18 2021
# Epoch:134 TrainLoss: 0.11594 ValidationLoss:  0.09497, Accuracy: 0.96259, Precision: 0.81815, Recall: 0.79105 F1: 0.80437, +: 370475, -: 4266733, False+: 97857, False-: 82343
# epoch 135 time Sat Oct 23 12:43:28 2021
# epoch 136 time Sat Oct 23 12:43:35 2021
# epoch 137 time Sat Oct 23 12:43:42 2021
# epoch 138 time Sat Oct 23 12:43:49 2021
# epoch 139 time Sat Oct 23 12:43:56 2021
# Epoch:139 TrainLoss: 0.11329 ValidationLoss:  0.09708, Accuracy: 0.96164, Precision: 0.85864, Recall: 0.72468 F1: 0.78599, +: 339393, -: 4293199, False+: 128939, False-: 55877
# epoch 140 time Sat Oct 23 12:44:07 2021
# epoch 141 time Sat Oct 23 12:44:14 2021
# epoch 142 time Sat Oct 23 12:44:21 2021
# epoch 143 time Sat Oct 23 12:44:28 2021
# epoch 144 time Sat Oct 23 12:44:35 2021
# Epoch:144 TrainLoss: 0.11500 ValidationLoss:  0.10020, Accuracy: 0.96063, Precision: 0.82271, Recall: 0.75848 F1: 0.78929, +: 355220, -: 4272530, False+: 113112, False-: 76546
# epoch 145 time Sat Oct 23 12:44:45 2021
# epoch 146 time Sat Oct 23 12:44:52 2021
# epoch 147 time Sat Oct 23 12:44:59 2021
# epoch 148 time Sat Oct 23 12:45:06 2021
# epoch 149 time Sat Oct 23 12:45:13 2021
# Epoch:149 TrainLoss: 0.11128 ValidationLoss:  0.09508, Accuracy: 0.96254, Precision: 0.83870, Recall: 0.76102 F1: 0.79797, +: 356409, -: 4280530, False+: 111923, False-: 68546
# epoch 150 time Sat Oct 23 12:45:24 2021
# epoch 151 time Sat Oct 23 12:45:31 2021
# epoch 152 time Sat Oct 23 12:45:38 2021
# epoch 153 time Sat Oct 23 12:45:45 2021
# epoch 154 time Sat Oct 23 12:45:52 2021
# Epoch:154 TrainLoss: 0.11034 ValidationLoss:  0.09809, Accuracy: 0.96135, Precision: 0.81709, Recall: 0.77615 F1: 0.79609, +: 363497, -: 4267703, False+: 104835, False-: 81373
# epoch 155 time Sat Oct 23 12:46:03 2021
# epoch 156 time Sat Oct 23 12:46:10 2021
# epoch 157 time Sat Oct 23 12:46:16 2021
# epoch 158 time Sat Oct 23 12:46:23 2021
# epoch 159 time Sat Oct 23 12:46:30 2021
# Epoch:159 TrainLoss: 0.11707 ValidationLoss:  0.09530, Accuracy: 0.96232, Precision: 0.82599, Recall: 0.77586 F1: 0.80014, +: 363360, -: 4272526, False+: 104972, False-: 76550
# epoch 160 time Sat Oct 23 12:46:41 2021
# epoch 161 time Sat Oct 23 12:46:48 2021
# epoch 162 time Sat Oct 23 12:46:55 2021
# epoch 163 time Sat Oct 23 12:47:02 2021
# epoch 164 time Sat Oct 23 12:47:09 2021
# Epoch:164 TrainLoss: 0.11327 ValidationLoss:  0.09592, Accuracy: 0.96261, Precision: 0.84010, Recall: 0.76004 F1: 0.79807, +: 355953, -: 4281326, False+: 112379, False-: 67750
# epoch 165 time Sat Oct 23 12:47:19 2021
# epoch 166 time Sat Oct 23 12:47:26 2021
# epoch 167 time Sat Oct 23 12:47:33 2021
# epoch 168 time Sat Oct 23 12:47:40 2021
# epoch 169 time Sat Oct 23 12:47:47 2021
# Epoch:169 TrainLoss: 0.11100 ValidationLoss:  0.09124, Accuracy: 0.96383, Precision: 0.83742, Recall: 0.77924 F1: 0.80728, +: 364942, -: 4278224, False+: 103390, False-: 70852
# epoch 170 time Sat Oct 23 12:47:58 2021
# epoch 171 time Sat Oct 23 12:48:05 2021
# epoch 172 time Sat Oct 23 12:48:12 2021
# epoch 173 time Sat Oct 23 12:48:19 2021
# epoch 174 time Sat Oct 23 12:48:26 2021
# Epoch:174 TrainLoss: 0.10964 ValidationLoss:  0.09142, Accuracy: 0.96381, Precision: 0.83596, Recall: 0.78093 F1: 0.80751, +: 365734, -: 4277309, False+: 102598, False-: 71767
# epoch 175 time Sat Oct 23 12:48:36 2021
# epoch 176 time Sat Oct 23 12:48:43 2021
# epoch 177 time Sat Oct 23 12:48:50 2021
# epoch 178 time Sat Oct 23 12:48:57 2021
# epoch 179 time Sat Oct 23 12:49:04 2021
# Epoch:179 TrainLoss: 0.11135 ValidationLoss:  0.09389, Accuracy: 0.96303, Precision: 0.82306, Recall: 0.78944 F1: 0.80590, +: 369722, -: 4269594, False+: 98610, False-: 79482
# epoch 180 time Sat Oct 23 12:49:15 2021
# epoch 181 time Sat Oct 23 12:49:22 2021
# epoch 182 time Sat Oct 23 12:49:29 2021
# epoch 183 time Sat Oct 23 12:49:36 2021
# epoch 184 time Sat Oct 23 12:49:43 2021
# Epoch:184 TrainLoss: 0.10696 ValidationLoss:  0.09320, Accuracy: 0.96290, Precision: 0.85221, Recall: 0.74811 F1: 0.79678, +: 350366, -: 4288317, False+: 117966, False-: 60759
# epoch 185 time Sat Oct 23 12:49:53 2021
# epoch 186 time Sat Oct 23 12:50:00 2021
# epoch 187 time Sat Oct 23 12:50:07 2021
# epoch 188 time Sat Oct 23 12:50:14 2021
# epoch 189 time Sat Oct 23 12:50:21 2021
# Epoch:189 TrainLoss: 0.10533 ValidationLoss:  0.09327, Accuracy: 0.96291, Precision: 0.84126, Recall: 0.76227 F1: 0.79982, +: 356996, -: 4281715, False+: 111336, False-: 67361
# epoch 190 time Sat Oct 23 12:50:32 2021
# epoch 191 time Sat Oct 23 12:50:39 2021
# epoch 192 time Sat Oct 23 12:50:46 2021
# epoch 193 time Sat Oct 23 12:50:53 2021
# epoch 194 time Sat Oct 23 12:51:00 2021
# Epoch:194 TrainLoss: 0.10888 ValidationLoss:  0.09216, Accuracy: 0.96349, Precision: 0.84810, Recall: 0.76066 F1: 0.80200, +: 356242, -: 4285271, False+: 112090, False-: 63805
# epoch 195 time Sat Oct 23 12:51:10 2021
# epoch 196 time Sat Oct 23 12:51:17 2021
# epoch 197 time Sat Oct 23 12:51:24 2021
# epoch 198 time Sat Oct 23 12:51:31 2021
# epoch 199 time Sat Oct 23 12:51:38 2021
# Epoch:199 TrainLoss: 0.11346 ValidationLoss:  0.09442, Accuracy: 0.96266, Precision: 0.82992, Recall: 0.77469 F1: 0.80136, +: 362812, -: 4274724, False+: 105520, False-: 74352
# epoch 200 time Sat Oct 23 12:51:49 2021
# epoch 201 time Sat Oct 23 12:51:56 2021
# epoch 202 time Sat Oct 23 12:52:03 2021
# epoch 203 time Sat Oct 23 12:52:10 2021
# epoch 204 time Sat Oct 23 12:52:17 2021
# Epoch:204 TrainLoss: 0.10681 ValidationLoss:  0.09177, Accuracy: 0.96369, Precision: 0.83183, Recall: 0.78522 F1: 0.80785, +: 367745, -: 4274729, False+: 100587, False-: 74347
# epoch 205 time Sat Oct 23 12:52:27 2021
# epoch 206 time Sat Oct 23 12:52:34 2021
# epoch 207 time Sat Oct 23 12:52:41 2021
# epoch 208 time Sat Oct 23 12:52:48 2021
# epoch 209 time Sat Oct 23 12:52:55 2021
# Epoch:209 TrainLoss: 0.10602 ValidationLoss:  0.09436, Accuracy: 0.96281, Precision: 0.84693, Recall: 0.75368 F1: 0.79759, +: 352971, -: 4285282, False+: 115361, False-: 63794
# epoch 210 time Sat Oct 23 12:53:06 2021
# epoch 211 time Sat Oct 23 12:53:13 2021
# epoch 212 time Sat Oct 23 12:53:20 2021
# epoch 213 time Sat Oct 23 12:53:27 2021
# epoch 214 time Sat Oct 23 12:53:34 2021
# Epoch:214 TrainLoss: 0.11392 ValidationLoss:  0.09380, Accuracy: 0.96238, Precision: 0.83125, Recall: 0.76912 F1: 0.79898, +: 360205, -: 4275951, False+: 108127, False-: 73125
# epoch 215 time Sat Oct 23 12:53:44 2021
# epoch 216 time Sat Oct 23 12:53:51 2021
# epoch 217 time Sat Oct 23 12:53:58 2021
# epoch 218 time Sat Oct 23 12:54:05 2021
# epoch 219 time Sat Oct 23 12:54:12 2021
# Epoch:219 TrainLoss: 0.10604 ValidationLoss:  0.09022, Accuracy: 0.96393, Precision: 0.82935, Recall: 0.79188 F1: 0.81018, +: 370862, -: 4272767, False+: 97470, False-: 76309
# epoch 220 time Sat Oct 23 12:54:22 2021
# epoch 221 time Sat Oct 23 12:54:29 2021
# epoch 222 time Sat Oct 23 12:54:36 2021
# epoch 223 time Sat Oct 23 12:54:43 2021
# epoch 224 time Sat Oct 23 12:54:50 2021
# Epoch:224 TrainLoss: 0.10647 ValidationLoss:  0.09027, Accuracy: 0.96406, Precision: 0.85732, Recall: 0.75615 F1: 0.80356, +: 354130, -: 4290140, False+: 114202, False-: 58936
# epoch 225 time Sat Oct 23 12:55:01 2021
# epoch 226 time Sat Oct 23 12:55:08 2021
# epoch 227 time Sat Oct 23 12:55:15 2021
# epoch 228 time Sat Oct 23 12:55:22 2021
# epoch 229 time Sat Oct 23 12:55:29 2021
# Epoch:229 TrainLoss: 0.10806 ValidationLoss:  0.09201, Accuracy: 0.96347, Precision: 0.84368, Recall: 0.76616 F1: 0.80305, +: 358818, -: 4282591, False+: 109514, False-: 66485
# epoch 230 time Sat Oct 23 12:55:39 2021
# epoch 231 time Sat Oct 23 12:55:46 2021
# epoch 232 time Sat Oct 23 12:55:53 2021
# epoch 233 time Sat Oct 23 12:56:00 2021
# epoch 234 time Sat Oct 23 12:56:07 2021
# Epoch:234 TrainLoss: 0.10440 ValidationLoss:  0.09281, Accuracy: 0.96284, Precision: 0.86977, Recall: 0.72654 F1: 0.79173, +: 340261, -: 4298131, False+: 128071, False-: 50945
# epoch 235 time Sat Oct 23 12:56:18 2021
# epoch 236 time Sat Oct 23 12:56:25 2021
# epoch 237 time Sat Oct 23 12:56:32 2021
# epoch 238 time Sat Oct 23 12:56:39 2021
# epoch 239 time Sat Oct 23 12:56:46 2021
# Epoch:239 TrainLoss: 0.10599 ValidationLoss:  0.09405, Accuracy: 0.96221, Precision: 0.85075, Recall: 0.74131 F1: 0.79227, +: 347180, -: 4288170, False+: 121152, False-: 60906
# epoch 240 time Sat Oct 23 12:56:56 2021
# epoch 241 time Sat Oct 23 12:57:03 2021
# epoch 242 time Sat Oct 23 12:57:10 2021
# epoch 243 time Sat Oct 23 12:57:17 2021
# epoch 244 time Sat Oct 23 12:57:24 2021
# Epoch:244 TrainLoss: 0.11001 ValidationLoss:  0.09134, Accuracy: 0.96344, Precision: 0.83306, Recall: 0.78026 F1: 0.80580, +: 365423, -: 4275846, False+: 102909, False-: 73230
# epoch 245 time Sat Oct 23 12:57:35 2021
# epoch 246 time Sat Oct 23 12:57:42 2021
# epoch 247 time Sat Oct 23 12:57:49 2021
# epoch 248 time Sat Oct 23 12:57:56 2021
# epoch 249 time Sat Oct 23 12:58:03 2021
# Epoch:249 TrainLoss: 0.10908 ValidationLoss:  0.09078, Accuracy: 0.96360, Precision: 0.84259, Recall: 0.76935 F1: 0.80431, +: 360309, -: 4281766, False+: 108023, False-: 67310
# epoch 250 time Sat Oct 23 12:58:13 2021
# epoch 251 time Sat Oct 23 12:58:20 2021
# epoch 252 time Sat Oct 23 12:58:27 2021
# epoch 253 time Sat Oct 23 12:58:34 2021
# epoch 254 time Sat Oct 23 12:58:41 2021
# Epoch:254 TrainLoss: 0.10891 ValidationLoss:  0.09224, Accuracy: 0.96322, Precision: 0.84739, Recall: 0.75822 F1: 0.80033, +: 355099, -: 4285125, False+: 113233, False-: 63951
# epoch 255 time Sat Oct 23 12:58:52 2021
# epoch 256 time Sat Oct 23 12:58:59 2021
# epoch 257 time Sat Oct 23 12:59:05 2021
# epoch 258 time Sat Oct 23 12:59:12 2021
# epoch 259 time Sat Oct 23 12:59:19 2021
# Epoch:259 TrainLoss: 0.10408 ValidationLoss:  0.09154, Accuracy: 0.96347, Precision: 0.83729, Recall: 0.77479 F1: 0.80483, +: 362857, -: 4278563, False+: 105475, False-: 70513
# epoch 260 time Sat Oct 23 12:59:30 2021
# epoch 261 time Sat Oct 23 12:59:37 2021
# epoch 262 time Sat Oct 23 12:59:44 2021
# epoch 263 time Sat Oct 23 12:59:51 2021
# epoch 264 time Sat Oct 23 12:59:58 2021
# Epoch:264 TrainLoss: 0.10391 ValidationLoss:  0.09040, Accuracy: 0.96384, Precision: 0.84429, Recall: 0.77003 F1: 0.80546, +: 360632, -: 4282568, False+: 107700, False-: 66508
# epoch 265 time Sat Oct 23 13:00:09 2021
# epoch 266 time Sat Oct 23 13:00:15 2021
# epoch 267 time Sat Oct 23 13:00:22 2021
# epoch 268 time Sat Oct 23 13:00:29 2021
# epoch 269 time Sat Oct 23 13:00:36 2021
# Epoch:269 TrainLoss: 0.10801 ValidationLoss:  0.09135, Accuracy: 0.96354, Precision: 0.85464, Recall: 0.75303 F1: 0.80063, +: 352670, -: 4289093, False+: 115662, False-: 59983
# epoch 270 time Sat Oct 23 13:00:47 2021
# epoch 271 time Sat Oct 23 13:00:54 2021
# epoch 272 time Sat Oct 23 13:01:01 2021
# epoch 273 time Sat Oct 23 13:01:08 2021
# epoch 274 time Sat Oct 23 13:01:15 2021
# Epoch:274 TrainLoss: 0.10420 ValidationLoss:  0.09284, Accuracy: 0.96305, Precision: 0.84623, Recall: 0.75760 F1: 0.79947, +: 354807, -: 4284604, False+: 113525, False-: 64472
# epoch 275 time Sat Oct 23 13:01:25 2021
# epoch 276 time Sat Oct 23 13:01:32 2021
# epoch 277 time Sat Oct 23 13:01:39 2021
# epoch 278 time Sat Oct 23 13:01:46 2021
# epoch 279 time Sat Oct 23 13:01:53 2021
# Epoch:279 TrainLoss: 0.10473 ValidationLoss:  0.09023, Accuracy: 0.96361, Precision: 0.83102, Recall: 0.78543 F1: 0.80758, +: 367843, -: 4274277, False+: 100489, False-: 74799
# epoch 280 time Sat Oct 23 13:02:04 2021
# epoch 281 time Sat Oct 23 13:02:11 2021
# epoch 282 time Sat Oct 23 13:02:18 2021
# epoch 283 time Sat Oct 23 13:02:25 2021
# epoch 284 time Sat Oct 23 13:02:32 2021
# Epoch:284 TrainLoss: 0.10584 ValidationLoss:  0.09207, Accuracy: 0.96304, Precision: 0.85202, Recall: 0.75011 F1: 0.79782, +: 351302, -: 4288059, False+: 117030, False-: 61017
# epoch 285 time Sat Oct 23 13:02:42 2021
# epoch 286 time Sat Oct 23 13:02:49 2021
# epoch 287 time Sat Oct 23 13:02:56 2021
# epoch 288 time Sat Oct 23 13:03:03 2021
# epoch 289 time Sat Oct 23 13:03:10 2021
# Epoch:289 TrainLoss: 0.10751 ValidationLoss:  0.09483, Accuracy: 0.96182, Precision: 0.87066, Recall: 0.71323 F1: 0.78412, +: 334029, -: 4299454, False+: 134303, False-: 49622
# epoch 290 time Sat Oct 23 13:03:21 2021
# epoch 291 time Sat Oct 23 13:03:28 2021
# epoch 292 time Sat Oct 23 13:03:35 2021
# epoch 293 time Sat Oct 23 13:03:42 2021
# epoch 294 time Sat Oct 23 13:03:49 2021
# Epoch:294 TrainLoss: 0.10515 ValidationLoss:  0.09142, Accuracy: 0.96316, Precision: 0.83565, Recall: 0.77305 F1: 0.80313, +: 362042, -: 4277872, False+: 106290, False-: 71204
# epoch 295 time Sat Oct 23 13:03:59 2021
# epoch 296 time Sat Oct 23 13:04:06 2021
# epoch 297 time Sat Oct 23 13:04:13 2021
# epoch 298 time Sat Oct 23 13:04:20 2021
# epoch 299 time Sat Oct 23 13:04:27 2021
# Epoch:299 TrainLoss: 0.10582 ValidationLoss:  0.09137, Accuracy: 0.96351, Precision: 0.82758, Recall: 0.78910 F1: 0.80788, +: 369561, -: 4272080, False+: 98771, False-: 76996
# epoch 300 time Sat Oct 23 13:04:38 2021
# epoch 301 time Sat Oct 23 13:04:45 2021
# epoch 302 time Sat Oct 23 13:04:51 2021
# epoch 303 time Sat Oct 23 13:04:58 2021
# epoch 304 time Sat Oct 23 13:05:05 2021
# Epoch:304 TrainLoss: 0.10371 ValidationLoss:  0.09062, Accuracy: 0.96381, Precision: 0.85039, Recall: 0.76180 F1: 0.80366, +: 356774, -: 4286307, False+: 111558, False-: 62769
# epoch 305 time Sat Oct 23 13:05:16 2021
# epoch 306 time Sat Oct 23 13:05:23 2021
# epoch 307 time Sat Oct 23 13:05:30 2021
# epoch 308 time Sat Oct 23 13:05:37 2021
# epoch 309 time Sat Oct 23 13:05:44 2021
# Epoch:309 TrainLoss: 0.10634 ValidationLoss:  0.09131, Accuracy: 0.96363, Precision: 0.81900, Recall: 0.80339 F1: 0.81112, +: 376253, -: 4265924, False+: 92079, False-: 83152
# epoch 310 time Sat Oct 23 13:05:55 2021
# epoch 311 time Sat Oct 23 13:06:02 2021
# epoch 312 time Sat Oct 23 13:06:09 2021
# epoch 313 time Sat Oct 23 13:06:15 2021
# epoch 314 time Sat Oct 23 13:06:22 2021
# Epoch:314 TrainLoss: 0.10460 ValidationLoss:  0.08967, Accuracy: 0.96403, Precision: 0.85733, Recall: 0.75578 F1: 0.80336, +: 353955, -: 4290173, False+: 114377, False-: 58903
# epoch 315 time Sat Oct 23 13:06:33 2021
# epoch 316 time Sat Oct 23 13:06:40 2021
# epoch 317 time Sat Oct 23 13:06:47 2021
# epoch 318 time Sat Oct 23 13:06:54 2021
# epoch 319 time Sat Oct 23 13:07:01 2021
# Epoch:319 TrainLoss: 0.10426 ValidationLoss:  0.09219, Accuracy: 0.96291, Precision: 0.81880, Recall: 0.79430 F1: 0.80636, +: 371996, -: 4266754, False+: 96336, False-: 82322
# epoch 320 time Sat Oct 23 13:07:12 2021
# epoch 321 time Sat Oct 23 13:07:18 2021
# epoch 322 time Sat Oct 23 13:07:25 2021
# epoch 323 time Sat Oct 23 13:07:32 2021
# epoch 324 time Sat Oct 23 13:07:39 2021
# Epoch:324 TrainLoss: 0.10091 ValidationLoss:  0.08870, Accuracy: 0.96442, Precision: 0.83947, Recall: 0.78387 F1: 0.81072, +: 367110, -: 4278873, False+: 101222, False-: 70203
# epoch 325 time Sat Oct 23 13:07:50 2021
# epoch 326 time Sat Oct 23 13:07:57 2021
# epoch 327 time Sat Oct 23 13:08:04 2021
# epoch 328 time Sat Oct 23 13:08:11 2021
# epoch 329 time Sat Oct 23 13:08:18 2021
# Epoch:329 TrainLoss: 0.10543 ValidationLoss:  0.09059, Accuracy: 0.96365, Precision: 0.82114, Recall: 0.80039 F1: 0.81063, +: 374847, -: 4267426, False+: 93485, False-: 81650
# epoch 330 time Sat Oct 23 13:08:29 2021
# epoch 331 time Sat Oct 23 13:08:35 2021
# epoch 332 time Sat Oct 23 13:08:42 2021
# epoch 333 time Sat Oct 23 13:08:49 2021
# epoch 334 time Sat Oct 23 13:08:56 2021
# Epoch:334 TrainLoss: 0.10410 ValidationLoss:  0.08985, Accuracy: 0.96382, Precision: 0.81276, Recall: 0.81574 F1: 0.81425, +: 382037, -: 4261065, False+: 86295, False-: 88011
# epoch 335 time Sat Oct 23 13:09:07 2021
# epoch 336 time Sat Oct 23 13:09:14 2021
# epoch 337 time Sat Oct 23 13:09:21 2021
# epoch 338 time Sat Oct 23 13:09:28 2021
# epoch 339 time Sat Oct 23 13:09:35 2021
# Epoch:339 TrainLoss: 0.10153 ValidationLoss:  0.09069, Accuracy: 0.96361, Precision: 0.82663, Recall: 0.79170 F1: 0.80879, +: 370778, -: 4271312, False+: 97554, False-: 77764
# epoch 340 time Sat Oct 23 13:09:45 2021
# epoch 341 time Sat Oct 23 13:09:52 2021
# epoch 342 time Sat Oct 23 13:09:59 2021
# epoch 343 time Sat Oct 23 13:10:06 2021
# epoch 344 time Sat Oct 23 13:10:13 2021
# Epoch:344 TrainLoss: 0.10281 ValidationLoss:  0.08803, Accuracy: 0.96428, Precision: 0.84357, Recall: 0.77654 F1: 0.80867, +: 363678, -: 4281634, False+: 104654, False-: 67442
# epoch 345 time Sat Oct 23 13:10:24 2021
# epoch 346 time Sat Oct 23 13:10:30 2021
# epoch 347 time Sat Oct 23 13:10:37 2021
# epoch 348 time Sat Oct 23 13:10:44 2021
# epoch 349 time Sat Oct 23 13:10:51 2021
# Epoch:349 TrainLoss: 0.10409 ValidationLoss:  0.08953, Accuracy: 0.96393, Precision: 0.83311, Recall: 0.78657 F1: 0.80917, +: 368375, -: 4275284, False+: 99957, False-: 73792
# epoch 350 time Sat Oct 23 13:11:02 2021
# epoch 351 time Sat Oct 23 13:11:09 2021
# epoch 352 time Sat Oct 23 13:11:16 2021
# epoch 353 time Sat Oct 23 13:11:23 2021
# epoch 354 time Sat Oct 23 13:11:30 2021
# Epoch:354 TrainLoss: 0.10348 ValidationLoss:  0.09046, Accuracy: 0.96367, Precision: 0.82605, Recall: 0.79336 F1: 0.80938, +: 371558, -: 4270832, False+: 96774, False-: 78244
# epoch 355 time Sat Oct 23 13:11:40 2021
# epoch 356 time Sat Oct 23 13:11:47 2021
# epoch 357 time Sat Oct 23 13:11:54 2021
# epoch 358 time Sat Oct 23 13:12:01 2021
# epoch 359 time Sat Oct 23 13:12:08 2021
# Epoch:359 TrainLoss: 0.10336 ValidationLoss:  0.08856, Accuracy: 0.96421, Precision: 0.84429, Recall: 0.77472 F1: 0.80801, +: 362827, -: 4282160, False+: 105505, False-: 66916
# epoch 360 time Sat Oct 23 13:12:19 2021
# epoch 361 time Sat Oct 23 13:12:26 2021
# epoch 362 time Sat Oct 23 13:12:33 2021
# epoch 363 time Sat Oct 23 13:12:40 2021
# epoch 364 time Sat Oct 23 13:12:47 2021
# Epoch:364 TrainLoss: 0.10168 ValidationLoss:  0.08894, Accuracy: 0.96425, Precision: 0.83888, Recall: 0.78259 F1: 0.80976, +: 366512, -: 4278683, False+: 101820, False-: 70393
# epoch 365 time Sat Oct 23 13:12:57 2021
# epoch 366 time Sat Oct 23 13:13:04 2021
# epoch 367 time Sat Oct 23 13:13:11 2021
# epoch 368 time Sat Oct 23 13:13:18 2021
# epoch 369 time Sat Oct 23 13:13:25 2021
# Epoch:369 TrainLoss: 0.10105 ValidationLoss:  0.08893, Accuracy: 0.96406, Precision: 0.83831, Recall: 0.78094 F1: 0.80861, +: 365741, -: 4278533, False+: 102591, False-: 70543
# epoch 370 time Sat Oct 23 13:13:36 2021
# epoch 371 time Sat Oct 23 13:13:43 2021
# epoch 372 time Sat Oct 23 13:13:50 2021
# epoch 373 time Sat Oct 23 13:13:57 2021
# epoch 374 time Sat Oct 23 13:14:04 2021
# Epoch:374 TrainLoss: 0.10160 ValidationLoss:  0.09259, Accuracy: 0.96269, Precision: 0.83805, Recall: 0.76381 F1: 0.79921, +: 357717, -: 4279949, False+: 110615, False-: 69127
# epoch 375 time Sat Oct 23 13:14:14 2021
# epoch 376 time Sat Oct 23 13:14:21 2021
# epoch 377 time Sat Oct 23 13:14:28 2021
# epoch 378 time Sat Oct 23 13:14:35 2021
# epoch 379 time Sat Oct 23 13:14:42 2021
# Epoch:379 TrainLoss: 0.10368 ValidationLoss:  0.08869, Accuracy: 0.96433, Precision: 0.83060, Recall: 0.79531 F1: 0.81257, +: 372467, -: 4273110, False+: 95865, False-: 75966
# epoch 380 time Sat Oct 23 13:14:53 2021
# epoch 381 time Sat Oct 23 13:15:00 2021
# epoch 382 time Sat Oct 23 13:15:07 2021
# epoch 383 time Sat Oct 23 13:15:14 2021
# epoch 384 time Sat Oct 23 13:15:20 2021
# Epoch:384 TrainLoss: 0.10333 ValidationLoss:  0.09181, Accuracy: 0.96306, Precision: 0.85983, Recall: 0.74079 F1: 0.79588, +: 346937, -: 4292518, False+: 121395, False-: 56558
# epoch 385 time Sat Oct 23 13:15:31 2021
# epoch 386 time Sat Oct 23 13:15:38 2021
# epoch 387 time Sat Oct 23 13:15:45 2021
# epoch 388 time Sat Oct 23 13:15:52 2021
# epoch 389 time Sat Oct 23 13:15:59 2021
# Epoch:389 TrainLoss: 0.10213 ValidationLoss:  0.08814, Accuracy: 0.96432, Precision: 0.84217, Recall: 0.77896 F1: 0.80933, +: 364812, -: 4280708, False+: 103520, False-: 68368
# epoch 390 time Sat Oct 23 13:16:09 2021
# epoch 391 time Sat Oct 23 13:16:16 2021
# epoch 392 time Sat Oct 23 13:16:23 2021
# epoch 393 time Sat Oct 23 13:16:30 2021
# epoch 394 time Sat Oct 23 13:16:37 2021
# Epoch:394 TrainLoss: 0.10185 ValidationLoss:  0.09067, Accuracy: 0.96363, Precision: 0.82473, Recall: 0.79481 F1: 0.80950, +: 372235, -: 4269972, False+: 96097, False-: 79104
# epoch 395 time Sat Oct 23 13:16:48 2021
# epoch 396 time Sat Oct 23 13:16:55 2021
# epoch 397 time Sat Oct 23 13:17:02 2021
# epoch 398 time Sat Oct 23 13:17:09 2021
# epoch 399 time Sat Oct 23 13:17:16 2021
# Epoch:399 TrainLoss: 0.10147 ValidationLoss:  0.08829, Accuracy: 0.96451, Precision: 0.85019, Recall: 0.77074 F1: 0.80852, +: 360964, -: 4285469, False+: 107368, False-: 63607
# epoch 400 time Sat Oct 23 13:17:26 2021
# epoch 401 time Sat Oct 23 13:17:33 2021
# epoch 402 time Sat Oct 23 13:17:40 2021
# epoch 403 time Sat Oct 23 13:17:47 2021
# epoch 404 time Sat Oct 23 13:17:54 2021
# Epoch:404 TrainLoss: 0.10012 ValidationLoss:  0.08911, Accuracy: 0.96360, Precision: 0.84018, Recall: 0.77258 F1: 0.80497, +: 361825, -: 4280251, False+: 106507, False-: 68825
# epoch 405 time Sat Oct 23 13:18:05 2021
# epoch 406 time Sat Oct 23 13:18:12 2021
# epoch 407 time Sat Oct 23 13:18:19 2021
# epoch 408 time Sat Oct 23 13:18:26 2021
# epoch 409 time Sat Oct 23 13:18:33 2021
# Epoch:409 TrainLoss: 0.10658 ValidationLoss:  0.08951, Accuracy: 0.96387, Precision: 0.85301, Recall: 0.75922 F1: 0.80339, +: 355569, -: 4287806, False+: 112763, False-: 61270
# epoch 410 time Sat Oct 23 13:18:43 2021
# epoch 411 time Sat Oct 23 13:18:50 2021
# epoch 412 time Sat Oct 23 13:18:57 2021
# epoch 413 time Sat Oct 23 13:19:04 2021
# epoch 414 time Sat Oct 23 13:19:11 2021
# Epoch:414 TrainLoss: 0.10049 ValidationLoss:  0.08834, Accuracy: 0.96440, Precision: 0.82934, Recall: 0.79804 F1: 0.81339, +: 373748, -: 4272165, False+: 94584, False-: 76911
# epoch 415 time Sat Oct 23 13:19:22 2021
# epoch 416 time Sat Oct 23 13:19:29 2021
# epoch 417 time Sat Oct 23 13:19:36 2021
# epoch 418 time Sat Oct 23 13:19:43 2021
# epoch 419 time Sat Oct 23 13:19:50 2021
# Epoch:419 TrainLoss: 0.09901 ValidationLoss:  0.08867, Accuracy: 0.96426, Precision: 0.83964, Recall: 0.78164 F1: 0.80960, +: 366065, -: 4279161, False+: 102267, False-: 69915
# epoch 420 time Sat Oct 23 13:20:00 2021
# epoch 421 time Sat Oct 23 13:20:07 2021
# epoch 422 time Sat Oct 23 13:20:14 2021
# epoch 423 time Sat Oct 23 13:20:21 2021
# epoch 424 time Sat Oct 23 13:20:28 2021
# Epoch:424 TrainLoss: 0.09981 ValidationLoss:  0.09124, Accuracy: 0.96320, Precision: 0.82771, Recall: 0.78489 F1: 0.80573, +: 367588, -: 4272561, False+: 100744, False-: 76515
# epoch 425 time Sat Oct 23 13:20:39 2021
# epoch 426 time Sat Oct 23 13:20:46 2021
# epoch 427 time Sat Oct 23 13:20:52 2021
# epoch 428 time Sat Oct 23 13:20:59 2021
# epoch 429 time Sat Oct 23 13:21:06 2021
# Epoch:429 TrainLoss: 0.10022 ValidationLoss:  0.08973, Accuracy: 0.96358, Precision: 0.83890, Recall: 0.77396 F1: 0.80512, +: 362471, -: 4279469, False+: 105861, False-: 69607
# epoch 430 time Sat Oct 23 13:21:17 2021
# epoch 431 time Sat Oct 23 13:21:24 2021
# epoch 432 time Sat Oct 23 13:21:31 2021
# epoch 433 time Sat Oct 23 13:21:38 2021
# epoch 434 time Sat Oct 23 13:21:45 2021
# Epoch:434 TrainLoss: 0.09891 ValidationLoss:  0.08790, Accuracy: 0.96434, Precision: 0.83665, Recall: 0.78682 F1: 0.81097, +: 368492, -: 4277130, False+: 99840, False-: 71946
# epoch 435 time Sat Oct 23 13:21:56 2021
# epoch 436 time Sat Oct 23 13:22:02 2021
# epoch 437 time Sat Oct 23 13:22:09 2021
# epoch 438 time Sat Oct 23 13:22:16 2021
# epoch 439 time Sat Oct 23 13:22:23 2021
# Epoch:439 TrainLoss: 0.09809 ValidationLoss:  0.08872, Accuracy: 0.96426, Precision: 0.83590, Recall: 0.78681 F1: 0.81061, +: 368488, -: 4276735, False+: 99844, False-: 72341
# epoch 440 time Sat Oct 23 13:22:34 2021
# epoch 441 time Sat Oct 23 13:22:41 2021
# epoch 442 time Sat Oct 23 13:22:48 2021
# epoch 443 time Sat Oct 23 13:22:55 2021
# epoch 444 time Sat Oct 23 13:23:02 2021
# Epoch:444 TrainLoss: 0.09796 ValidationLoss:  0.08952, Accuracy: 0.96406, Precision: 0.84544, Recall: 0.77137 F1: 0.80671, +: 361256, -: 4283031, False+: 107076, False-: 66045
# epoch 445 time Sat Oct 23 13:23:12 2021
# epoch 446 time Sat Oct 23 13:23:19 2021
# epoch 447 time Sat Oct 23 13:23:26 2021
# epoch 448 time Sat Oct 23 13:23:33 2021
# epoch 449 time Sat Oct 23 13:23:40 2021
# Epoch:449 TrainLoss: 0.09742 ValidationLoss:  0.08940, Accuracy: 0.96379, Precision: 0.85553, Recall: 0.75507 F1: 0.80217, +: 353624, -: 4289363, False+: 114708, False-: 59713
# epoch 450 time Sat Oct 23 13:23:51 2021
# epoch 451 time Sat Oct 23 13:23:58 2021
# epoch 452 time Sat Oct 23 13:24:05 2021
# epoch 453 time Sat Oct 23 13:24:12 2021
# epoch 454 time Sat Oct 23 13:24:19 2021
# Epoch:454 TrainLoss: 0.09848 ValidationLoss:  0.09036, Accuracy: 0.96366, Precision: 0.81375, Recall: 0.81212 F1: 0.81293, +: 380340, -: 4262027, False+: 87992, False-: 87049
# epoch 455 time Sat Oct 23 13:24:29 2021
# epoch 456 time Sat Oct 23 13:24:36 2021
# epoch 457 time Sat Oct 23 13:24:43 2021
# epoch 458 time Sat Oct 23 13:24:50 2021
# epoch 459 time Sat Oct 23 13:24:57 2021
# Epoch:459 TrainLoss: 0.09972 ValidationLoss:  0.08871, Accuracy: 0.96417, Precision: 0.81781, Recall: 0.81239 F1: 0.81509, +: 380467, -: 4264319, False+: 87865, False-: 84757
# epoch 460 time Sat Oct 23 13:25:08 2021
# epoch 461 time Sat Oct 23 13:25:15 2021
# epoch 462 time Sat Oct 23 13:25:22 2021
# epoch 463 time Sat Oct 23 13:25:29 2021
# epoch 464 time Sat Oct 23 13:25:36 2021
# Epoch:464 TrainLoss: 0.09979 ValidationLoss:  0.08827, Accuracy: 0.96424, Precision: 0.83600, Recall: 0.78645 F1: 0.81047, +: 368322, -: 4276823, False+: 100010, False-: 72253
# epoch 465 time Sat Oct 23 13:25:46 2021
# epoch 466 time Sat Oct 23 13:25:53 2021
# epoch 467 time Sat Oct 23 13:26:00 2021
# epoch 468 time Sat Oct 23 13:26:07 2021
# epoch 469 time Sat Oct 23 13:26:14 2021
# Epoch:469 TrainLoss: 0.09942 ValidationLoss:  0.09241, Accuracy: 0.96302, Precision: 0.83342, Recall: 0.77440 F1: 0.80282, +: 362674, -: 4276585, False+: 105658, False-: 72491
# epoch 470 time Sat Oct 23 13:26:25 2021
# epoch 471 time Sat Oct 23 13:26:32 2021
# epoch 472 time Sat Oct 23 13:26:39 2021
# epoch 473 time Sat Oct 23 13:26:46 2021
# epoch 474 time Sat Oct 23 13:26:53 2021
# Epoch:474 TrainLoss: 0.09771 ValidationLoss:  0.08905, Accuracy: 0.96418, Precision: 0.83243, Recall: 0.79067 F1: 0.81101, +: 370297, -: 4274532, False+: 98035, False-: 74544
# epoch 475 time Sat Oct 23 13:27:03 2021
# epoch 476 time Sat Oct 23 13:27:10 2021
# epoch 477 time Sat Oct 23 13:27:17 2021
# epoch 478 time Sat Oct 23 13:27:24 2021
# epoch 479 time Sat Oct 23 13:27:31 2021
# Epoch:479 TrainLoss: 0.09747 ValidationLoss:  0.09038, Accuracy: 0.96370, Precision: 0.82421, Recall: 0.79642 F1: 0.81008, +: 372989, -: 4269525, False+: 95343, False-: 79551
# epoch 480 time Sat Oct 23 13:27:41 2021
# epoch 481 time Sat Oct 23 13:27:48 2021
# epoch 482 time Sat Oct 23 13:27:55 2021
# epoch 483 time Sat Oct 23 13:28:02 2021
# epoch 484 time Sat Oct 23 13:28:09 2021
# Epoch:484 TrainLoss: 0.09701 ValidationLoss:  0.09202, Accuracy: 0.96312, Precision: 0.80900, Recall: 0.81240 F1: 0.81069, +: 380471, -: 4259249, False+: 87861, False-: 89827
# epoch 485 time Sat Oct 23 13:28:20 2021
# epoch 486 time Sat Oct 23 13:28:27 2021
# epoch 487 time Sat Oct 23 13:28:34 2021
# epoch 488 time Sat Oct 23 13:28:41 2021
# epoch 489 time Sat Oct 23 13:28:48 2021
# Epoch:489 TrainLoss: 0.09677 ValidationLoss:  0.08927, Accuracy: 0.96385, Precision: 0.84575, Recall: 0.76825 F1: 0.80514, +: 359798, -: 4283454, False+: 108534, False-: 65622
# epoch 490 time Sat Oct 23 13:28:59 2021
# epoch 491 time Sat Oct 23 13:29:06 2021
# epoch 492 time Sat Oct 23 13:29:12 2021
# epoch 493 time Sat Oct 23 13:29:19 2021
# epoch 494 time Sat Oct 23 13:29:26 2021
# Epoch:494 TrainLoss: 0.09488 ValidationLoss:  0.08881, Accuracy: 0.96426, Precision: 0.83859, Recall: 0.78313 F1: 0.80991, +: 366766, -: 4278481, False+: 101566, False-: 70595
# epoch 495 time Sat Oct 23 13:29:37 2021
# epoch 496 time Sat Oct 23 13:29:44 2021
# epoch 497 time Sat Oct 23 13:29:51 2021
# epoch 498 time Sat Oct 23 13:29:58 2021
# epoch 499 time Sat Oct 23 13:30:05 2021
# Epoch:499 TrainLoss: 0.09449 ValidationLoss:  0.09157, Accuracy: 0.96356, Precision: 0.83357, Recall: 0.78118 F1: 0.80653, +: 365852, -: 4276032, False+: 102480, False-: 73044
# epoch 500 time Sat Oct 23 13:30:15 2021
# epoch 501 time Sat Oct 23 13:30:22 2021
# epoch 502 time Sat Oct 23 13:30:29 2021
# epoch 503 time Sat Oct 23 13:30:36 2021
# epoch 504 time Sat Oct 23 13:30:43 2021
# Epoch:504 TrainLoss: 0.09499 ValidationLoss:  0.09054, Accuracy: 0.96364, Precision: 0.84687, Recall: 0.76422 F1: 0.80342, +: 357909, -: 4284358, False+: 110423, False-: 64718
# epoch 505 time Sat Oct 23 13:30:54 2021
# epoch 506 time Sat Oct 23 13:31:01 2021
# epoch 507 time Sat Oct 23 13:31:08 2021
# epoch 508 time Sat Oct 23 13:31:14 2021
# epoch 509 time Sat Oct 23 13:31:21 2021
# Epoch:509 TrainLoss: 0.09596 ValidationLoss:  0.08945, Accuracy: 0.96396, Precision: 0.82208, Recall: 0.80306 F1: 0.81246, +: 376100, -: 4267677, False+: 92232, False-: 81399
# epoch 510 time Sat Oct 23 13:31:32 2021
# epoch 511 time Sat Oct 23 13:31:39 2021
# epoch 512 time Sat Oct 23 13:31:46 2021
# epoch 513 time Sat Oct 23 13:31:53 2021
# epoch 514 time Sat Oct 23 13:32:00 2021
# Epoch:514 TrainLoss: 0.09432 ValidationLoss:  0.08875, Accuracy: 0.96428, Precision: 0.85409, Recall: 0.76296 F1: 0.80596, +: 357320, -: 4288033, False+: 111012, False-: 61043
# epoch 515 time Sat Oct 23 13:32:11 2021
# epoch 516 time Sat Oct 23 13:32:17 2021
# epoch 517 time Sat Oct 23 13:32:24 2021
# epoch 518 time Sat Oct 23 13:32:31 2021
# epoch 519 time Sat Oct 23 13:32:38 2021
# Epoch:519 TrainLoss: 0.09463 ValidationLoss:  0.08866, Accuracy: 0.96449, Precision: 0.85616, Recall: 0.76287 F1: 0.80683, +: 357276, -: 4289052, False+: 111056, False-: 60024
# epoch 520 time Sat Oct 23 13:32:49 2021
# epoch 521 time Sat Oct 23 13:32:56 2021
# epoch 522 time Sat Oct 23 13:33:03 2021
# epoch 523 time Sat Oct 23 13:33:10 2021
# epoch 524 time Sat Oct 23 13:33:17 2021
# Epoch:524 TrainLoss: 0.09533 ValidationLoss:  0.09012, Accuracy: 0.96356, Precision: 0.83413, Recall: 0.78032 F1: 0.80633, +: 365451, -: 4276407, False+: 102881, False-: 72669
# epoch 525 time Sat Oct 23 13:33:27 2021
# epoch 526 time Sat Oct 23 13:33:34 2021
# epoch 527 time Sat Oct 23 13:33:41 2021
# epoch 528 time Sat Oct 23 13:33:48 2021
# epoch 529 time Sat Oct 23 13:33:55 2021
# Epoch:529 TrainLoss: 0.09469 ValidationLoss:  0.08882, Accuracy: 0.96434, Precision: 0.83528, Recall: 0.78875 F1: 0.81135, +: 369399, -: 4276230, False+: 98933, False-: 72846
# epoch 530 time Sat Oct 23 13:34:06 2021
# epoch 531 time Sat Oct 23 13:34:13 2021
# epoch 532 time Sat Oct 23 13:34:20 2021
# epoch 533 time Sat Oct 23 13:34:27 2021
# epoch 534 time Sat Oct 23 13:34:34 2021
# Epoch:534 TrainLoss: 0.09715 ValidationLoss:  0.09216, Accuracy: 0.96343, Precision: 0.85177, Recall: 0.75527 F1: 0.80062, +: 353717, -: 4287522, False+: 114615, False-: 61554
# epoch 535 time Sat Oct 23 13:34:44 2021
# epoch 536 time Sat Oct 23 13:34:51 2021
# epoch 537 time Sat Oct 23 13:34:58 2021
# epoch 538 time Sat Oct 23 13:35:05 2021
# epoch 539 time Sat Oct 23 13:35:12 2021
# Epoch:539 TrainLoss: 0.09278 ValidationLoss:  0.09037, Accuracy: 0.96391, Precision: 0.81498, Recall: 0.81340 F1: 0.81419, +: 380940, -: 4262591, False+: 87392, False-: 86485
# epoch 540 time Sat Oct 23 13:35:23 2021
# epoch 541 time Sat Oct 23 13:35:30 2021
# epoch 542 time Sat Oct 23 13:35:37 2021
# epoch 543 time Sat Oct 23 13:35:44 2021
# epoch 544 time Sat Oct 23 13:35:51 2021
# Epoch:544 TrainLoss: 0.09277 ValidationLoss:  0.09326, Accuracy: 0.96264, Precision: 0.80192, Recall: 0.81767 F1: 0.80972, +: 382940, -: 4254487, False+: 85392, False-: 94589
# epoch 545 time Sat Oct 23 13:36:01 2021
# epoch 546 time Sat Oct 23 13:36:08 2021
# epoch 547 time Sat Oct 23 13:36:15 2021
# epoch 548 time Sat Oct 23 13:36:22 2021
# epoch 549 time Sat Oct 23 13:36:29 2021
# Epoch:549 TrainLoss: 0.09331 ValidationLoss:  0.09239, Accuracy: 0.96321, Precision: 0.81423, Recall: 0.80524 F1: 0.80971, +: 377118, -: 4263036, False+: 91214, False-: 86040
# epoch 550 time Sat Oct 23 13:36:40 2021
# epoch 551 time Sat Oct 23 13:36:47 2021
# epoch 552 time Sat Oct 23 13:36:54 2021
# epoch 553 time Sat Oct 23 13:37:01 2021
# epoch 554 time Sat Oct 23 13:37:08 2021
# Epoch:554 TrainLoss: 0.09405 ValidationLoss:  0.09165, Accuracy: 0.96345, Precision: 0.81800, Recall: 0.80260 F1: 0.81022, +: 375881, -: 4265445, False+: 92451, False-: 83631
# epoch 555 time Sat Oct 23 13:37:18 2021
# epoch 556 time Sat Oct 23 13:37:25 2021
# epoch 557 time Sat Oct 23 13:37:32 2021
# epoch 558 time Sat Oct 23 13:37:39 2021
# epoch 559 time Sat Oct 23 13:37:46 2021
# Epoch:559 TrainLoss: 0.09346 ValidationLoss:  0.09058, Accuracy: 0.96377, Precision: 0.81926, Recall: 0.80488 F1: 0.81201, +: 376950, -: 4265917, False+: 91382, False-: 83159
# epoch 560 time Sat Oct 23 13:37:57 2021
# epoch 561 time Sat Oct 23 13:38:04 2021
# epoch 562 time Sat Oct 23 13:38:11 2021
# epoch 563 time Sat Oct 23 13:38:18 2021
# epoch 564 time Sat Oct 23 13:38:25 2021
# Epoch:564 TrainLoss: 0.09628 ValidationLoss:  0.09184, Accuracy: 0.96313, Precision: 0.84076, Recall: 0.76584 F1: 0.80155, +: 358667, -: 4281145, False+: 109665, False-: 67931
# epoch 565 time Sat Oct 23 13:38:35 2021
# epoch 566 time Sat Oct 23 13:38:42 2021
# epoch 567 time Sat Oct 23 13:38:49 2021
# epoch 568 time Sat Oct 23 13:38:56 2021
# epoch 569 time Sat Oct 23 13:39:03 2021
# Epoch:569 TrainLoss: 0.09020 ValidationLoss:  0.09296, Accuracy: 0.96367, Precision: 0.83287, Recall: 0.78349 F1: 0.80742, +: 366932, -: 4275445, False+: 101400, False-: 73631
# epoch 570 time Sat Oct 23 13:39:14 2021
# epoch 571 time Sat Oct 23 13:39:21 2021
# epoch 572 time Sat Oct 23 13:39:28 2021
# epoch 573 time Sat Oct 23 13:39:35 2021
# epoch 574 time Sat Oct 23 13:39:41 2021
# Epoch:574 TrainLoss: 0.09194 ValidationLoss:  0.09131, Accuracy: 0.96376, Precision: 0.83816, Recall: 0.77726 F1: 0.80657, +: 364018, -: 4278790, False+: 104314, False-: 70286
# epoch 575 time Sat Oct 23 13:39:52 2021
# epoch 576 time Sat Oct 23 13:39:59 2021
# epoch 577 time Sat Oct 23 13:40:06 2021
# epoch 578 time Sat Oct 23 13:40:13 2021
# epoch 579 time Sat Oct 23 13:40:20 2021
# Epoch:579 TrainLoss: 0.09172 ValidationLoss:  0.09614, Accuracy: 0.96280, Precision: 0.85005, Recall: 0.74961 F1: 0.79668, +: 351065, -: 4287149, False+: 117267, False-: 61927
# epoch 580 time Sat Oct 23 13:40:31 2021
# epoch 581 time Sat Oct 23 13:40:38 2021
# epoch 582 time Sat Oct 23 13:40:44 2021
# epoch 583 time Sat Oct 23 13:40:51 2021
# epoch 584 time Sat Oct 23 13:40:58 2021
# Epoch:584 TrainLoss: 0.09383 ValidationLoss:  0.08983, Accuracy: 0.96402, Precision: 0.84876, Recall: 0.76647 F1: 0.80552, +: 358964, -: 4285114, False+: 109368, False-: 63962
# epoch 585 time Sat Oct 23 13:41:09 2021
# epoch 586 time Sat Oct 23 13:41:16 2021
# epoch 587 time Sat Oct 23 13:41:23 2021
# epoch 588 time Sat Oct 23 13:41:30 2021
# epoch 589 time Sat Oct 23 13:41:37 2021
# Epoch:589 TrainLoss: 0.09178 ValidationLoss:  0.09009, Accuracy: 0.96400, Precision: 0.82881, Recall: 0.79355 F1: 0.81080, +: 371647, -: 4272313, False+: 96685, False-: 76763
# epoch 590 time Sat Oct 23 13:41:47 2021
# epoch 591 time Sat Oct 23 13:41:54 2021
# epoch 592 time Sat Oct 23 13:42:01 2021
# epoch 593 time Sat Oct 23 13:42:08 2021
# epoch 594 time Sat Oct 23 13:42:15 2021
# Epoch:594 TrainLoss: 0.09255 ValidationLoss:  0.09386, Accuracy: 0.96302, Precision: 0.82096, Recall: 0.79239 F1: 0.80642, +: 371103, -: 4268145, False+: 97229, False-: 80931
# epoch 595 time Sat Oct 23 13:42:26 2021
# epoch 596 time Sat Oct 23 13:42:33 2021
# epoch 597 time Sat Oct 23 13:42:40 2021
# epoch 598 time Sat Oct 23 13:42:46 2021
# epoch 599 time Sat Oct 23 13:42:53 2021
# Epoch:599 TrainLoss: 0.08907 ValidationLoss:  0.09231, Accuracy: 0.96398, Precision: 0.84201, Recall: 0.77490 F1: 0.80706, +: 362911, -: 4280982, False+: 105421, False-: 68094
# epoch 600 time Sat Oct 23 13:43:04 2021
# epoch 601 time Sat Oct 23 13:43:11 2021
# epoch 602 time Sat Oct 23 13:43:18 2021
# epoch 603 time Sat Oct 23 13:43:25 2021
# epoch 604 time Sat Oct 23 13:43:32 2021
# Epoch:604 TrainLoss: 0.09076 ValidationLoss:  0.09264, Accuracy: 0.96322, Precision: 0.81440, Recall: 0.80522 F1: 0.80978, +: 377111, -: 4263133, False+: 91221, False-: 85943
# epoch 605 time Sat Oct 23 13:43:43 2021
# epoch 606 time Sat Oct 23 13:43:49 2021
# epoch 607 time Sat Oct 23 13:43:56 2021
# epoch 608 time Sat Oct 23 13:44:03 2021
# epoch 609 time Sat Oct 23 13:44:10 2021
# Epoch:609 TrainLoss: 0.09227 ValidationLoss:  0.09129, Accuracy: 0.96405, Precision: 0.83729, Recall: 0.78217 F1: 0.80879, +: 366315, -: 4277890, False+: 102017, False-: 71186
# epoch 610 time Sat Oct 23 13:44:21 2021
# epoch 611 time Sat Oct 23 13:44:28 2021
# epoch 612 time Sat Oct 23 13:44:35 2021
# epoch 613 time Sat Oct 23 13:44:42 2021
# epoch 614 time Sat Oct 23 13:44:49 2021
# Epoch:614 TrainLoss: 0.09155 ValidationLoss:  0.09299, Accuracy: 0.96342, Precision: 0.81294, Recall: 0.81013 F1: 0.81153, +: 379410, -: 4261775, False+: 88922, False-: 87301
# epoch 615 time Sat Oct 23 13:44:59 2021
# epoch 616 time Sat Oct 23 13:45:06 2021
# epoch 617 time Sat Oct 23 13:45:13 2021
# epoch 618 time Sat Oct 23 13:45:20 2021
# epoch 619 time Sat Oct 23 13:45:27 2021
# Epoch:619 TrainLoss: 0.09064 ValidationLoss:  0.09284, Accuracy: 0.96359, Precision: 0.84371, Recall: 0.76774 F1: 0.80393, +: 359556, -: 4282471, False+: 108776, False-: 66605
# epoch 620 time Sat Oct 23 13:45:38 2021
# epoch 621 time Sat Oct 23 13:45:45 2021
# epoch 622 time Sat Oct 23 13:45:52 2021
# epoch 623 time Sat Oct 23 13:45:59 2021
# epoch 624 time Sat Oct 23 13:46:06 2021
# Epoch:624 TrainLoss: 0.09039 ValidationLoss:  0.09340, Accuracy: 0.96361, Precision: 0.85268, Recall: 0.75634 F1: 0.80163, +: 354220, -: 4287874, False+: 114112, False-: 61202
# epoch 625 time Sat Oct 23 13:46:16 2021
# epoch 626 time Sat Oct 23 13:46:23 2021
# epoch 627 time Sat Oct 23 13:46:30 2021
# epoch 628 time Sat Oct 23 13:46:37 2021
# epoch 629 time Sat Oct 23 13:46:44 2021
# Epoch:629 TrainLoss: 0.08614 ValidationLoss:  0.09650, Accuracy: 0.96241, Precision: 0.81185, Recall: 0.79839 F1: 0.80506, +: 373912, -: 4262421, False+: 94420, False-: 86655
# epoch 630 time Sat Oct 23 13:46:55 2021
# epoch 631 time Sat Oct 23 13:47:02 2021
# epoch 632 time Sat Oct 23 13:47:09 2021
# epoch 633 time Sat Oct 23 13:47:16 2021
# epoch 634 time Sat Oct 23 13:47:22 2021
# Epoch:634 TrainLoss: 0.08726 ValidationLoss:  0.09365, Accuracy: 0.96321, Precision: 0.82118, Recall: 0.79455 F1: 0.80764, +: 372112, -: 4268044, False+: 96220, False-: 81032
# epoch 635 time Sat Oct 23 13:47:33 2021
# epoch 636 time Sat Oct 23 13:47:40 2021
# epoch 637 time Sat Oct 23 13:47:47 2021
# epoch 638 time Sat Oct 23 13:47:54 2021
# epoch 639 time Sat Oct 23 13:48:01 2021
# Epoch:639 TrainLoss: 0.08490 ValidationLoss:  0.09150, Accuracy: 0.96398, Precision: 0.82853, Recall: 0.79371 F1: 0.81075, +: 371720, -: 4272148, False+: 96612, False-: 76928
# epoch 640 time Sat Oct 23 13:48:12 2021
# ...
# epoch 789 time Sat Oct 23 14:07:13 2021
# Epoch:789 TrainLoss: 0.07773 ValidationLoss:  0.10652, Accuracy: 0.96188, Precision: 0.82706, Recall: 0.76865 F1: 0.79679, +: 359984, -: 4273805, False+: 108348, False-: 75271
# epoch 790 time Sat Oct 23 14:07:24 2021
# epoch 791 time Sat Oct 23 14:07:30 2021
# epoch 792 time Sat Oct 23 14:07:37 2021
# epoch 793 time Sat Oct 23 14:07:44 2021
# epoch 794 time Sat Oct 23 14:07:51 2021
# Epoch:794 TrainLoss: 0.07569 ValidationLoss:  0.10503, Accuracy: 0.96167, Precision: 0.80297, Recall: 0.80263 F1: 0.80280, +: 375896, -: 4256841, False+: 92436, False-: 92235
# epoch 795 time Sat Oct 23 14:08:02 2021
# epoch 796 time Sat Oct 23 14:08:09 2021
# epoch 797 time Sat Oct 23 14:08:16 2021
# epoch 798 time Sat Oct 23 14:08:23 2021
# epoch 799 time Sat Oct 23 14:08:30 2021
# Epoch:799 TrainLoss: 0.07554 ValidationLoss:  0.10247, Accuracy: 0.96162, Precision: 0.80935, Recall: 0.79166 F1: 0.80041, +: 370762, -: 4261739, False+: 97570, False-: 87337
# epoch 800 time Sat Oct 23 14:08:41 2021
# epoch 801 time Sat Oct 23 14:08:48 2021
# epoch 802 time Sat Oct 23 14:08:55 2021
# epoch 803 time Sat Oct 23 14:09:01 2021
# epoch 804 time Sat Oct 23 14:09:08 2021
# Epoch:804 TrainLoss: 0.07363 ValidationLoss:  0.10396, Accuracy: 0.96234, Precision: 0.81532, Recall: 0.79198 F1: 0.80348, +: 370910, -: 4265061, False+: 97422, False-: 84015
# epoch 805 time Sat Oct 23 14:09:19 2021
# epoch 806 time Sat Oct 23 14:09:26 2021
# epoch 807 time Sat Oct 23 14:09:33 2021
# epoch 808 time Sat Oct 23 14:09:40 2021
# epoch 809 time Sat Oct 23 14:09:47 2021
# Epoch:809 TrainLoss: 0.07399 ValidationLoss:  0.10544, Accuracy: 0.96145, Precision: 0.80260, Recall: 0.80027 F1: 0.80143, +: 374794, -: 4256894, False+: 93538, False-: 92182
# epoch 810 time Sat Oct 23 14:09:57 2021
# epoch 811 time Sat Oct 23 14:10:04 2021
# epoch 812 time Sat Oct 23 14:10:11 2021
# epoch 813 time Sat Oct 23 14:10:18 2021
# epoch 814 time Sat Oct 23 14:10:25 2021
# Epoch:814 TrainLoss: 0.07447 ValidationLoss:  0.10393, Accuracy: 0.96220, Precision: 0.82782, Recall: 0.77172 F1: 0.79879, +: 361422, -: 4273905, False+: 106910, False-: 75171
# epoch 815 time Sat Oct 23 14:10:36 2021
# epoch 816 time Sat Oct 23 14:10:43 2021
# epoch 817 time Sat Oct 23 14:10:49 2021
# epoch 818 time Sat Oct 23 14:10:56 2021
# epoch 819 time Sat Oct 23 14:11:03 2021
# Epoch:819 TrainLoss: 0.07357 ValidationLoss:  0.10615, Accuracy: 0.96153, Precision: 0.80798, Recall: 0.79272 F1: 0.80028, +: 371254, -: 4260848, False+: 97078, False-: 88228
# epoch 820 time Sat Oct 23 14:11:14 2021
# epoch 821 time Sat Oct 23 14:11:21 2021
# epoch 822 time Sat Oct 23 14:11:28 2021
# epoch 823 time Sat Oct 23 14:11:35 2021
# epoch 824 time Sat Oct 23 14:11:42 2021
# Epoch:824 TrainLoss: 0.07333 ValidationLoss:  0.10610, Accuracy: 0.96138, Precision: 0.80846, Recall: 0.78989 F1: 0.79907, +: 369933, -: 4261432, False+: 98399, False-: 87644
# epoch 825 time Sat Oct 23 14:11:52 2021
# epoch 826 time Sat Oct 23 14:11:59 2021
# epoch 827 time Sat Oct 23 14:12:06 2021
# epoch 828 time Sat Oct 23 14:12:13 2021
# epoch 829 time Sat Oct 23 14:12:20 2021
# Epoch:829 TrainLoss: 0.07297 ValidationLoss:  0.10897, Accuracy: 0.96154, Precision: 0.82021, Recall: 0.77408 F1: 0.79648, +: 362525, -: 4269610, False+: 105807, False-: 79466
# epoch 830 time Sat Oct 23 14:12:31 2021
# epoch 831 time Sat Oct 23 14:12:38 2021
# epoch 832 time Sat Oct 23 14:12:45 2021
# epoch 833 time Sat Oct 23 14:12:52 2021
# epoch 834 time Sat Oct 23 14:12:59 2021
# Epoch:834 TrainLoss: 0.07022 ValidationLoss:  0.11186, Accuracy: 0.96127, Precision: 0.81662, Recall: 0.77589 F1: 0.79573, +: 363373, -: 4267479, False+: 104959, False-: 81597
# epoch 835 time Sat Oct 23 14:13:09 2021
# epoch 836 time Sat Oct 23 14:13:16 2021
# epoch 837 time Sat Oct 23 14:13:23 2021
# epoch 838 time Sat Oct 23 14:13:30 2021
# epoch 839 time Sat Oct 23 14:13:37 2021
# Epoch:839 TrainLoss: 0.07297 ValidationLoss:  0.11073, Accuracy: 0.96183, Precision: 0.83377, Recall: 0.75867 F1: 0.79445, +: 355311, -: 4278236, False+: 113021, False-: 70840
# epoch 840 time Sat Oct 23 14:13:48 2021
# epoch 841 time Sat Oct 23 14:13:55 2021
# epoch 842 time Sat Oct 23 14:14:02 2021
# epoch 843 time Sat Oct 23 14:14:09 2021
# epoch 844 time Sat Oct 23 14:14:15 2021
# Epoch:844 TrainLoss: 0.07220 ValidationLoss:  0.10910, Accuracy: 0.96074, Precision: 0.79986, Recall: 0.79509 F1: 0.79747, +: 372365, -: 4255905, False+: 95967, False-: 93171
# epoch 845 time Sat Oct 23 14:14:26 2021
# epoch 846 time Sat Oct 23 14:14:33 2021
# epoch 847 time Sat Oct 23 14:14:40 2021
# epoch 848 time Sat Oct 23 14:14:47 2021
# epoch 849 time Sat Oct 23 14:14:54 2021
# Epoch:849 TrainLoss: 0.06889 ValidationLoss:  0.11206, Accuracy: 0.96043, Precision: 0.80681, Recall: 0.77969 F1: 0.79301, +: 365152, -: 4261638, False+: 103180, False-: 87438
# epoch 850 time Sat Oct 23 14:15:04 2021
# epoch 851 time Sat Oct 23 14:15:11 2021
# epoch 852 time Sat Oct 23 14:15:18 2021
# epoch 853 time Sat Oct 23 14:15:25 2021
# epoch 854 time Sat Oct 23 14:15:32 2021
# Epoch:854 TrainLoss: 0.06814 ValidationLoss:  0.11693, Accuracy: 0.95996, Precision: 0.80552, Recall: 0.77537 F1: 0.79015, +: 363129, -: 4261403, False+: 105203, False-: 87673
# epoch 855 time Sat Oct 23 14:15:43 2021
# epoch 856 time Sat Oct 23 14:15:50 2021
# epoch 857 time Sat Oct 23 14:15:57 2021
# epoch 858 time Sat Oct 23 14:16:03 2021
# epoch 859 time Sat Oct 23 14:16:10 2021
# Epoch:859 TrainLoss: 0.06751 ValidationLoss:  0.10998, Accuracy: 0.96143, Precision: 0.82090, Recall: 0.77155 F1: 0.79546, +: 361340, -: 4270240, False+: 106992, False-: 78836
# epoch 860 time Sat Oct 23 14:16:21 2021
# epoch 861 time Sat Oct 23 14:16:28 2021
# epoch 862 time Sat Oct 23 14:16:35 2021
# epoch 863 time Sat Oct 23 14:16:42 2021
# epoch 864 time Sat Oct 23 14:16:49 2021
# Epoch:864 TrainLoss: 0.07179 ValidationLoss:  0.11009, Accuracy: 0.96088, Precision: 0.80386, Recall: 0.79046 F1: 0.79711, +: 370200, -: 4258748, False+: 98132, False-: 90328
# epoch 865 time Sat Oct 23 14:16:59 2021
# epoch 866 time Sat Oct 23 14:17:06 2021
# epoch 867 time Sat Oct 23 14:17:13 2021
# epoch 868 time Sat Oct 23 14:17:20 2021
# epoch 869 time Sat Oct 23 14:17:27 2021
# Epoch:869 TrainLoss: 0.06853 ValidationLoss:  0.10678, Accuracy: 0.96153, Precision: 0.80580, Recall: 0.79613 F1: 0.80094, +: 372851, -: 4259220, False+: 95481, False-: 89856
# epoch 870 time Sat Oct 23 14:17:38 2021
# epoch 871 time Sat Oct 23 14:17:45 2021
# epoch 872 time Sat Oct 23 14:17:52 2021
# epoch 873 time Sat Oct 23 14:17:59 2021
# epoch 874 time Sat Oct 23 14:18:06 2021
# Epoch:874 TrainLoss: 0.07009 ValidationLoss:  0.11253, Accuracy: 0.96025, Precision: 0.80535, Recall: 0.77958 F1: 0.79226, +: 365102, -: 4260835, False+: 103230, False-: 88241
# epoch 875 time Sat Oct 23 14:18:16 2021
# epoch 876 time Sat Oct 23 14:18:23 2021
# epoch 877 time Sat Oct 23 14:18:30 2021
# epoch 878 time Sat Oct 23 14:18:37 2021
# epoch 879 time Sat Oct 23 14:18:44 2021
# Epoch:879 TrainLoss: 0.06809 ValidationLoss:  0.11732, Accuracy: 0.95948, Precision: 0.78073, Recall: 0.81095 F1: 0.79555, +: 379792, -: 4242409, False+: 88540, False-: 106667
# epoch 880 time Sat Oct 23 14:18:55 2021
# epoch 881 time Sat Oct 23 14:19:02 2021
# epoch 882 time Sat Oct 23 14:19:09 2021
# epoch 883 time Sat Oct 23 14:19:16 2021
# epoch 884 time Sat Oct 23 14:19:23 2021
# Epoch:884 TrainLoss: 0.06801 ValidationLoss:  0.11243, Accuracy: 0.96119, Precision: 0.81987, Recall: 0.76996 F1: 0.79413, +: 360599, -: 4269849, False+: 107733, False-: 79227
# epoch 885 time Sat Oct 23 14:19:33 2021
# epoch 886 time Sat Oct 23 14:19:40 2021
# epoch 887 time Sat Oct 23 14:19:47 2021
# epoch 888 time Sat Oct 23 14:19:54 2021
# epoch 889 time Sat Oct 23 14:20:01 2021
# Epoch:889 TrainLoss: 0.06616 ValidationLoss:  0.11638, Accuracy: 0.96081, Precision: 0.81137, Recall: 0.77767 F1: 0.79416, +: 364209, -: 4264401, False+: 104123, False-: 84675
# epoch 890 time Sat Oct 23 14:20:12 2021
# epoch 891 time Sat Oct 23 14:20:19 2021
# epoch 892 time Sat Oct 23 14:20:26 2021
# epoch 893 time Sat Oct 23 14:20:33 2021
# epoch 894 time Sat Oct 23 14:20:40 2021
# Epoch:894 TrainLoss: 0.06558 ValidationLoss:  0.11691, Accuracy: 0.95965, Precision: 0.79849, Recall: 0.78247 F1: 0.79040, +: 366455, -: 4256594, False+: 101877, False-: 92482
# epoch 895 time Sat Oct 23 14:20:50 2021
# epoch 896 time Sat Oct 23 14:20:57 2021
# epoch 897 time Sat Oct 23 14:21:04 2021
# epoch 898 time Sat Oct 23 14:21:11 2021
# epoch 899 time Sat Oct 23 14:21:18 2021
# Epoch:899 TrainLoss: 0.06524 ValidationLoss:  0.11387, Accuracy: 0.96035, Precision: 0.80003, Recall: 0.78949 F1: 0.79473, +: 369745, -: 4256659, False+: 98587, False-: 92417
# epoch 900 time Sat Oct 23 14:21:29 2021
# epoch 901 time Sat Oct 23 14:21:36 2021
# epoch 902 time Sat Oct 23 14:21:43 2021
# epoch 903 time Sat Oct 23 14:21:50 2021
# epoch 904 time Sat Oct 23 14:21:57 2021
# Epoch:904 TrainLoss: 0.06481 ValidationLoss:  0.11725, Accuracy: 0.96078, Precision: 0.82066, Recall: 0.76341 F1: 0.79100, +: 357529, -: 4270946, False+: 110803, False-: 78130
# epoch 905 time Sat Oct 23 14:22:07 2021
# epoch 906 time Sat Oct 23 14:22:14 2021
# epoch 907 time Sat Oct 23 14:22:21 2021
# epoch 908 time Sat Oct 23 14:22:28 2021
# epoch 909 time Sat Oct 23 14:22:35 2021
# Epoch:909 TrainLoss: 0.06405 ValidationLoss:  0.11895, Accuracy: 0.95995, Precision: 0.80947, Recall: 0.76910 F1: 0.78877, +: 360196, -: 4264295, False+: 108136, False-: 84781
# epoch 910 time Sat Oct 23 14:22:46 2021
# epoch 911 time Sat Oct 23 14:22:53 2021
# epoch 912 time Sat Oct 23 14:23:00 2021
# epoch 913 time Sat Oct 23 14:23:07 2021
# epoch 914 time Sat Oct 23 14:23:14 2021
# Epoch:914 TrainLoss: 0.06609 ValidationLoss:  0.11958, Accuracy: 0.95968, Precision: 0.78602, Recall: 0.80421 F1: 0.79501, +: 376635, -: 4246541, False+: 91697, False-: 102535
# epoch 915 time Sat Oct 23 14:23:24 2021
# epoch 916 time Sat Oct 23 14:23:31 2021
# epoch 917 time Sat Oct 23 14:23:38 2021
# epoch 918 time Sat Oct 23 14:23:45 2021
# epoch 919 time Sat Oct 23 14:23:52 2021
# Epoch:919 TrainLoss: 0.06326 ValidationLoss:  0.12159, Accuracy: 0.95815, Precision: 0.77354, Recall: 0.80528 F1: 0.78909, +: 377138, -: 4238665, False+: 91194, False-: 110411
# epoch 920 time Sat Oct 23 14:24:03 2021
# epoch 921 time Sat Oct 23 14:24:10 2021
# epoch 922 time Sat Oct 23 14:24:17 2021
# epoch 923 time Sat Oct 23 14:24:24 2021
# epoch 924 time Sat Oct 23 14:24:31 2021
# Epoch:924 TrainLoss: 0.06439 ValidationLoss:  0.12215, Accuracy: 0.95946, Precision: 0.79466, Recall: 0.78620 F1: 0.79041, +: 368202, -: 4253931, False+: 100130, False-: 95145
# epoch 925 time Sat Oct 23 14:24:41 2021
# epoch 926 time Sat Oct 23 14:24:48 2021
# epoch 927 time Sat Oct 23 14:24:55 2021
# epoch 928 time Sat Oct 23 14:25:02 2021
# epoch 929 time Sat Oct 23 14:25:09 2021
# Epoch:929 TrainLoss: 0.06400 ValidationLoss:  0.11695, Accuracy: 0.96043, Precision: 0.80991, Recall: 0.77480 F1: 0.79197, +: 362864, -: 4263912, False+: 105468, False-: 85164
# epoch 930 time Sat Oct 23 14:25:20 2021
# epoch 931 time Sat Oct 23 14:25:27 2021
# epoch 932 time Sat Oct 23 14:25:34 2021
# epoch 933 time Sat Oct 23 14:25:41 2021
# epoch 934 time Sat Oct 23 14:25:47 2021
# Epoch:934 TrainLoss: 0.06327 ValidationLoss:  0.11926, Accuracy: 0.96000, Precision: 0.80399, Recall: 0.77832 F1: 0.79095, +: 364513, -: 4260208, False+: 103819, False-: 88868
# epoch 935 time Sat Oct 23 14:25:58 2021
# epoch 936 time Sat Oct 23 14:26:05 2021
# epoch 937 time Sat Oct 23 14:26:12 2021
# epoch 938 time Sat Oct 23 14:26:19 2021
# epoch 939 time Sat Oct 23 14:26:26 2021
# Epoch:939 TrainLoss: 0.06077 ValidationLoss:  0.12406, Accuracy: 0.95987, Precision: 0.79866, Recall: 0.78507 F1: 0.79181, +: 367675, -: 4256389, False+: 100657, False-: 92687
# epoch 940 time Sat Oct 23 14:26:36 2021
# epoch 941 time Sat Oct 23 14:26:43 2021
# epoch 942 time Sat Oct 23 14:26:50 2021
# epoch 943 time Sat Oct 23 14:26:57 2021
# epoch 944 time Sat Oct 23 14:27:04 2021
# Epoch:944 TrainLoss: 0.05891 ValidationLoss:  0.12335, Accuracy: 0.96002, Precision: 0.79882, Recall: 0.78690 F1: 0.79281, +: 368529, -: 4256261, False+: 99803, False-: 92815
# epoch 945 time Sat Oct 23 14:27:15 2021
# epoch 946 time Sat Oct 23 14:27:22 2021
# epoch 947 time Sat Oct 23 14:27:29 2021
# epoch 948 time Sat Oct 23 14:27:35 2021
# epoch 949 time Sat Oct 23 14:27:42 2021
# Epoch:949 TrainLoss: 0.06136 ValidationLoss:  0.11948, Accuracy: 0.95974, Precision: 0.79299, Recall: 0.79289 F1: 0.79294, +: 371335, -: 4252137, False+: 96997, False-: 96939
# epoch 950 time Sat Oct 23 14:27:53 2021
# epoch 951 time Sat Oct 23 14:28:00 2021
# epoch 952 time Sat Oct 23 14:28:07 2021
# epoch 953 time Sat Oct 23 14:28:14 2021
# epoch 954 time Sat Oct 23 14:28:21 2021
# Epoch:954 TrainLoss: 0.06209 ValidationLoss:  0.12088, Accuracy: 0.95928, Precision: 0.78825, Recall: 0.79456 F1: 0.79139, +: 372120, -: 4249111, False+: 96212, False-: 99965
# epoch 955 time Sat Oct 23 14:28:32 2021
# epoch 956 time Sat Oct 23 14:28:39 2021
# epoch 957 time Sat Oct 23 14:28:46 2021
# epoch 958 time Sat Oct 23 14:28:53 2021
# epoch 959 time Sat Oct 23 14:29:00 2021
# Epoch:959 TrainLoss: 0.06049 ValidationLoss:  0.12333, Accuracy: 0.96087, Precision: 0.81570, Recall: 0.77194 F1: 0.79322, +: 361525, -: 4267393, False+: 106807, False-: 81683
# epoch 960 time Sat Oct 23 14:29:11 2021
# epoch 961 time Sat Oct 23 14:29:18 2021
# epoch 962 time Sat Oct 23 14:29:25 2021
# epoch 963 time Sat Oct 23 14:29:31 2021
# epoch 964 time Sat Oct 23 14:29:38 2021
# Epoch:964 TrainLoss: 0.05899 ValidationLoss:  0.12351, Accuracy: 0.95994, Precision: 0.79083, Recall: 0.79937 F1: 0.79508, +: 374372, -: 4250058, False+: 93960, False-: 99018
# epoch 965 time Sat Oct 23 14:29:49 2021
# epoch 966 time Sat Oct 23 14:29:56 2021
# epoch 967 time Sat Oct 23 14:30:03 2021
# epoch 968 time Sat Oct 23 14:30:10 2021
# epoch 969 time Sat Oct 23 14:30:17 2021
# Epoch:969 TrainLoss: 0.05898 ValidationLoss:  0.12383, Accuracy: 0.96123, Precision: 0.81981, Recall: 0.77057 F1: 0.79443, +: 360881, -: 4269758, False+: 107451, False-: 79318
# epoch 970 time Sat Oct 23 14:30:27 2021
# epoch 971 time Sat Oct 23 14:30:34 2021
# epoch 972 time Sat Oct 23 14:30:41 2021
# epoch 973 time Sat Oct 23 14:30:48 2021
# epoch 974 time Sat Oct 23 14:30:55 2021
# Epoch:974 TrainLoss: 0.05787 ValidationLoss:  0.12795, Accuracy: 0.96001, Precision: 0.80744, Recall: 0.77303 F1: 0.78986, +: 362037, -: 4262736, False+: 106295, False-: 86340
# epoch 975 time Sat Oct 23 14:31:06 2021
# epoch 976 time Sat Oct 23 14:31:12 2021
# epoch 977 time Sat Oct 23 14:31:19 2021
# epoch 978 time Sat Oct 23 14:31:26 2021
# epoch 979 time Sat Oct 23 14:31:33 2021
# Epoch:979 TrainLoss: 0.05775 ValidationLoss:  0.13049, Accuracy: 0.95923, Precision: 0.79706, Recall: 0.77897 F1: 0.78791, +: 364818, -: 4256190, False+: 103514, False-: 92886
# epoch 980 time Sat Oct 23 14:31:44 2021
# epoch 981 time Sat Oct 23 14:31:51 2021
# epoch 982 time Sat Oct 23 14:31:58 2021
# epoch 983 time Sat Oct 23 14:32:05 2021
# epoch 984 time Sat Oct 23 14:32:12 2021
# Epoch:984 TrainLoss: 0.05703 ValidationLoss:  0.12847, Accuracy: 0.95977, Precision: 0.79476, Recall: 0.79030 F1: 0.79252, +: 370123, -: 4253496, False+: 98209, False-: 95580
# epoch 985 time Sat Oct 23 14:32:22 2021
# epoch 986 time Sat Oct 23 14:32:29 2021
# epoch 987 time Sat Oct 23 14:32:36 2021
# epoch 988 time Sat Oct 23 14:32:43 2021
# epoch 989 time Sat Oct 23 14:32:50 2021
# Epoch:989 TrainLoss: 0.05830 ValidationLoss:  0.12393, Accuracy: 0.95943, Precision: 0.79592, Recall: 0.78362 F1: 0.78972, +: 366995, -: 4254974, False+: 101337, False-: 94102
# epoch 990 time Sat Oct 23 14:33:01 2021
# epoch 991 time Sat Oct 23 14:33:08 2021
# epoch 992 time Sat Oct 23 14:33:15 2021
# epoch 993 time Sat Oct 23 14:33:22 2021
# epoch 994 time Sat Oct 23 14:33:29 2021
# Epoch:994 TrainLoss: 0.05912 ValidationLoss:  0.12891, Accuracy: 0.95853, Precision: 0.78414, Recall: 0.79123 F1: 0.78767, +: 370556, -: 4247067, False+: 97776, False-: 102009
# epoch 995 time Sat Oct 23 14:33:39 2021
# epoch 996 time Sat Oct 23 14:33:46 2021
# epoch 997 time Sat Oct 23 14:33:53 2021
# epoch 998 time Sat Oct 23 14:34:00 2021
# epoch 999 time Sat Oct 23 14:34:07 2021
# Epoch:999 TrainLoss: 0.05695 ValidationLoss:  0.13004, Accuracy: 0.95991, Precision: 0.79993, Recall: 0.78366 F1: 0.79171, +: 367015, -: 4257281, False+: 101317, False-: 91795

# %%
print('statsrec', statsrec)
#visulize the accuracy and the training loss and the validation loss
fig, ax1 = plt.subplots()
x_ = [validation_round*(p+1)for p in range(0, len(statsrec[0]))]
plt.plot(x_, statsrec[0], 'r', label = 'training loss', )
plt.plot(x_, statsrec[1], 'g', label = 'validation loss' )
plt.legend(loc='center')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Training and validation loss and validation accuracy')
ax2=ax1.twinx()
ax2.plot(x_, statsrec[2], 'b', label = 'validation accuracy')
ax2.plot(x_, statsrec[3], 'k', label = 'validation precision')
ax2.plot(x_, statsrec[4], 'y', label = 'validation recall')
ax2.plot(x_, statsrec[5], 'm', label = 'validation f1 score')
ax2.set_ylabel('accuracy')
plt.legend(loc='upper left')
plt.show()
# Out:
# statsrec [[0.20904299 0.16131066 0.15466106 ... 0.05829527 0.05911649 0.05694772]
#  [0.17683092 0.1418731  0.13727403 ... 0.12393427 0.12890684 0.13004134]
#  [0.94320577 0.95053214 0.9530617  ... 0.95943069 0.95852852 0.95991373]
#  [0.78372467 0.75747663 0.79759675 ... 0.79591715 0.78413761 0.79992807]
#  [0.5742721  0.72247463 0.6930511  ... 0.78362143 0.79122502 0.78366417]
#  [0.66284579 0.73956174 0.74165785 ... 0.78972149 0.78766531 0.79171264]]

# %%
##visulaize the confusion matrix
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix of valiation set', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(cmtensor, ['false', 'true'])
# Out:
# Confusion matrix, without normalization
# tensor([[4257281,   91795],
#         [ 101317,  367015]], dtype=torch.int32)

# %%
def load_checkpoint(path):
    from code.model import UNet
    model_checkpoint = torch.load(path)
    #print('model_checkpoint',model_checkpoint)
    #net2 = UNet(3,2)
    #print('model_checkpoint', type(model_checkpoint), model_checkpoint)
    #net_part = model_checkpoint['state_dict']
    #print('net_part',net_part)
    #net2.load_state_dict(net_part)
   # net2.load_state_dict(model_checkpoint['state_dict'])
    
    return model_checkpoint.to(device)
    #optimizer.load_state_dict(model_checkpoint['optimizer'])
    #return model, optimizer

net2 = load_checkpoint('models/00500.pkl')
net = net2

# %%
from code.trainer import predict_method, calc_loss


statsrec = [[],[],[],[],[],[],[],[]]
if not lp_method:
    all_outputs = []
    with torch.no_grad():
        for i, data in enumerate(validate_loader, 0):
            inputs_cpu, labels_cpu, _ = data
            inputs, labels = inputs_cpu.to(device), labels_cpu.to(device)
                
            outputs = net(inputs)
            outputs = F.softmax(outputs, 1)
            outputs = outputs.permute(1, 0, 2, 3)
            outputs = outputs[1]
            labels = labels.int()
            all_outputs.append((outputs, labels))

    for i in range(100):
        threshold = 0.01 * i
        positive, negative, false_negative, false_positive = 0, 0, 0, 0
        for outputs, labels in all_outputs:
            #print('sum', outputs.shape, outputs.sum())
            predicted = torch.where(outputs>threshold, 1, 0)
            #_, predicted = torch.max(outputs, 1)
            #labels = images.long()
            predicted = predicted.int()
            zeros = torch.zeros(labels.shape).to(device).int()
            #print('images1', images1)
            not_labels = 1 - labels
            positive       += torch.where(predicted==labels, labels, zeros).sum()
            negative       += torch.where(predicted==labels, not_labels, zeros).sum()
            false_negative += torch.where(predicted!=labels, labels, zeros).sum()
            false_positive += torch.where(predicted!=labels, not_labels, zeros).sum()
            #print(positive_right, negative_right, positive_wrong, negative_wrong)
        #print(threshold, positive_right, negative_right, positive_wrong, negative_wrong)
        statsrec[0].append(positive)    
        statsrec[1].append(negative)    
        statsrec[2].append(false_negative)    
        statsrec[3].append(false_positive)

# %%
from PIL import Image
import matplotlib.pyplot as plt


for p in range(4):
    statsrec[p] = [q.cpu() for q in statsrec[p]]

def draw_threshold_pics():
    #print('statsrec', statsrec)
    #visulize the accuracy and the training loss and the validation loss
    fig, ax1 = plt.subplots()
    plt.plot(statsrec[0], 'r', label = 'positive', )
    plt.plot(statsrec[1], 'g', label = 'negative' )
    plt.plot(statsrec[2], 'b', label = 'false negative' )
    plt.plot(statsrec[3], 'y', label = 'false positive' )
    #print('stat',statsrec)
    plt.legend(loc='center')
    plt.xlabel('threshold(%)')
    plt.ylabel('count')
    plt.title('Threshold')
    #ax2=ax1.twinx()
    #ax2.plot(statsrec[2], 'b', label = 'validation accuracy')
    #ax2.set_ylabel('accuracy')
    #plt.legend(loc='upper left')
    plt.show()

    fig, ax1 = plt.subplots()
    plt.plot(statsrec[0], 'r', label = 'positive', )
    plt.legend(loc='center')
    plt.xlabel('threshold(%)')
    plt.ylabel('count')
    plt.title('Threshold')
    plt.show()

    fig, ax1 = plt.subplots()
    plt.plot(statsrec[1], 'g', label = 'negative' )
    plt.legend(loc='center')
    plt.xlabel('threshold(%)')
    plt.ylabel('count')
    plt.title('Threshold')
    plt.show()

    fig, ax1 = plt.subplots()
    plt.plot(statsrec[2], 'b', label = 'false negative' )
    plt.legend(loc='center')
    plt.xlabel('threshold(%)')
    plt.ylabel('count')
    plt.title('Threshold')
    plt.show()

    fig, ax1 = plt.subplots()
    plt.plot(statsrec[3], 'y', label = 'false positive' )
    plt.legend(loc='center')
    plt.xlabel('threshold(%)')
    plt.ylabel('count')
    plt.title('Threshold')
    plt.show()

if not lp_method:
    draw_threshold_pics()

# %%
if not lp_method:
    precisions = []
    recalls = []
    accs = []
    f1s = []
    for p in range(len(statsrec[0])):
        acc1 = (statsrec[0][p] + statsrec[1][p]) / (statsrec[0][p] + statsrec[1][p] + statsrec[2][p] + statsrec[3][p])
        accs.append(acc1)
        precision1 = statsrec[0][p]  / (statsrec[0][p] + statsrec[2][p])
        precisions.append(precision1)
        recall1 = statsrec[0][p]  / (statsrec[0][p] + statsrec[3][p])
        recalls.append(recall1)
        f1_score = 2*precision1*recall1/(precision1+recall1)
        f1s.append(f1_score)

    fig, ax1 = plt.subplots()
    plt.plot(accs, 'r', label = 'accuracy', )
    plt.plot(recalls, 'g', label = 'recall', )
    plt.plot(precisions, 'b', label = 'precision', )
    plt.plot(f1s, 'k', label = 'f1 score', )
    plt.legend(loc='center')
    plt.xlabel('threshold(%)')
    plt.ylabel('%')
    plt.title('Threshold')
    #ax2=ax1.twinx()
    #ax2.plot(statsrec[2], 'b', label = 'validation accuracy')
    #ax2.set_ylabel('accuracy')
    #plt.legend(loc='upper left')
    plt.show()

# %%
from code.draw_helper import draw_one_area

# draw one sample patch
data_image, label_image, predicted_image = draw_one_area(dataset_test, 0)

plt.imshow(data_image)
plt.show()

plt.imshow(label_image)
plt.show()

plt.imshow(predicted_image)
plt.show()

# %%
from code.draw_helper import draw_patches


data_image, label_image, predicted_image = draw_patches(dataset_test, 0)

plt.imshow(data_image)
plt.show()

plt.imshow(label_image)
plt.show()

plt.imshow(predicted_image)
plt.show()

# %%
from code.draw_helper import draw_full


data_image, label_image, predicted_image = draw_full(dataset_test, 0)

plt.imshow(data_image)
plt.show()

plt.imshow(label_image)
plt.show()

plt.imshow(predicted_image)
plt.show()

# %%
from code.draw_helper import draw_full

test_len = dataset_test.length()
index = 1
colomn_number = 2
line_number = (test_len - 1)//colomn_number + 1
colomn_number = colomn_number * 3

#print('len', test_len, colomn_number, line_number)
plt.figure(2)
for i in range(test_len):
    data_image, label_image, predicted_image = draw_full(dataset_test, i)
    for q in [data_image, label_image, predicted_image]:
        plt.subplot(line_number, colomn_number, index)
        index = index + 1
        plt.imshow(q)
        plt.xticks([])
        plt.yticks([])
        plt.axis('off')
plt.show()

# %%
from code.trainer import test_one_batch

ltst, positive, negative, false_negative, false_positive, was, als = test_one_batch(test_loader, True)

right = positive + negative
wrong = false_negative + false_positive
total = right + wrong
accuracy = right / total
precision = positive / (positive + false_positive)
recall = positive / (positive + false_negative)
print(f'Accuracy:{accuracy: .5f}, Precision:{precision: .5f}, Recall:{recall: .5f}')
#print('was', was, als)
for p in range(200):
    if als[1000+p] != 0:
        print(f'+{p:3d},{was[1000+p]:8d}/{als[1000+p]:8d}={was[1000+p]/als[1000+p]}')

for p in range(200):
    if als[1000-p] != 0:
        print(f'-{p:3d},{was[1000-p]:8d}/{als[1000-p]:8d}={was[1000-p]/als[1000-p]}')
# Out:
# Accuracy: 0.96067, Precision: 0.80963, Recall: 0.79981
# +  1,   90811/  264294=0.3435984169144967
# +  2,    6186/  135193=0.04575680693527032
# +  3,     435/   62036=0.007012057514991296
# +  4,     136/   20272=0.006708760852407261
# +  5,      63/    4853=0.012981660828353597
# +  6,      40/    1050=0.0380952380952381
# +  7,      12/     227=0.05286343612334802
# +  8,       1/      25=0.04
# +  9,       0/       4=0.0
# -  1,   71550/  302167=0.23678958986255944
# -  2,    8866/  286187=0.030979744013529615
# -  3,    1689/  272694=0.006193755638187859
# -  4,    1156/  258719=0.0044681681670074485
# -  5,     966/  244504=0.003950855609724176
# -  6,     821/  230577=0.0035606326736838455
# -  7,     756/  216064=0.0034989632701421802
# -  8,     712/  199791=0.0035637240916758014
# -  9,     669/  184121=0.003633480157070622
# - 10,     582/  167561=0.0034733619398308675
# - 11,     495/  151043=0.003277212449434929
# - 12,     438/  134815=0.0032488966361309945
# - 13,     385/  119189=0.0032301638574029484
# - 14,     327/  105171=0.003109222123969535
# - 15,     314/   92122=0.003408523479733397
# - 16,     247/   80298=0.003076041744501731
# - 17,     223/   70255=0.0031741513059568714
# - 18,     209/   61464=0.003400364440973578
# - 19,     171/   54183=0.003155971430153369
# - 20,     169/   48099=0.003513586561051165
# - 21,     144/   43224=0.003331482509716824
# - 22,     153/   39364=0.0038868001219388272
# - 23,     123/   35925=0.0034237995824634654
# - 24,     111/   32825=0.0033815689261233817
# - 25,      92/   30474=0.0030189669882522805
# - 26,      82/   28198=0.002908007660117739
# - 27,      59/   26141=0.0022569909337821813
# - 28,      42/   24476=0.0017159666612191534
# - 29,      26/   23039=0.0011285212031772213
# - 30,      21/   21710=0.0009672961768770152
# - 31,      24/   20654=0.0011620025176721216
# - 32,      16/   19730=0.0008109477952356817
# - 33,      15/   18829=0.0007966434754899357
# - 34,      17/   17856=0.0009520609318996416
# - 35,      13/   17048=0.0007625527921163773
# - 36,      12/   16415=0.0007310386841303686
# - 37,       7/   15804=0.000442925841559099
# - 38,       8/   15119=0.0005291355248362987
# - 39,       3/   14541=0.00020631318341242006
# - 40,       1/   14017=7.134194192765928e-05
# - 41,       0/   13537=0.0
# - 42,       0/   13087=0.0
# - 43,       2/   12707=0.00015739356260328953
# - 44,       1/   12304=8.127438231469441e-05
# - 45,       0/   11878=0.0
# - 46,       0/   11494=0.0
# - 47,       1/   11155=8.964589870013447e-05
# - 48,       1/   10849=9.217439395335975e-05
# - 49,       1/   10472=9.549274255156608e-05
# - 50,       0/   10165=0.0
# - 51,       0/    9858=0.0
# - 52,       1/    9604=0.00010412328196584757
# - 53,       1/    9366=0.00010676916506512919
# - 54,       4/    9093=0.00043989882327064776
# - 55,       3/    8821=0.000340097494615123
# - 56,       2/    8560=0.00023364485981308412
# - 57,       2/    8339=0.0002398369109005876
# - 58,       1/    8144=0.00012278978388998034
# - 59,       1/    7955=0.0001257071024512885
# - 60,       1/    7758=0.0001288992008249549
# - 61,       0/    7558=0.0
# - 62,       1/    7362=0.00013583265417006248
# - 63,       1/    7174=0.00013939224979091162
# - 64,       0/    6998=0.0
# - 65,       1/    6814=0.000146756677428823
# - 66,       1/    6659=0.0001501726986033939
# - 67,       0/    6503=0.0
# - 68,       1/    6352=0.00015743073047858942
# - 69,       0/    6220=0.0
# - 70,       0/    6098=0.0
# - 71,       1/    5964=0.00016767270288397049
# - 72,       0/    5833=0.0
# - 73,       1/    5728=0.00017458100558659218
# - 74,       1/    5633=0.00017752529735487306
# - 75,       0/    5543=0.0
# - 76,       1/    5451=0.000183452577508714
# - 77,       0/    5368=0.0
# - 78,       1/    5296=0.00018882175226586103
# - 79,       1/    5223=0.00019146084625694046
# - 80,       1/    5140=0.0001945525291828794
# - 81,       1/    5042=0.00019833399444664816
# - 82,       2/    4962=0.00040306328093510683
# - 83,       1/    4878=0.0002050020500205002
# - 84,       1/    4813=0.00020777062123415748
# - 85,       1/    4751=0.00021048200378867606
# - 86,       1/    4688=0.00021331058020477816
# - 87,       1/    4601=0.00021734405564007825
# - 88,       0/    4501=0.0
# - 89,       1/    4427=0.00022588660492432798
# - 90,       1/    4353=0.00022972662531587412
# - 91,       0/    4278=0.0
# - 92,       1/    4213=0.00023736055067647758
# - 93,       1/    4138=0.0002416626389560174
# - 94,       1/    4067=0.00024588148512417015
# - 95,       1/    3979=0.00025131942699170643
# - 96,       1/    3899=0.00025647601949217746
# - 97,       1/    3811=0.0002623983206507478
# - 98,       1/    3730=0.00026809651474530834
# - 99,       0/    3644=0.0
# -100,       0/    3581=0.0
# -101,       0/    3515=0.0
# -102,       0/    3450=0.0
# -103,       0/    3400=0.0
# -104,       0/    3344=0.0
# -105,       0/    3298=0.0
# -106,       0/    3253=0.0
# -107,       0/    3210=0.0
# -108,       0/    3158=0.0
# -109,       0/    3114=0.0
# -110,       0/    3072=0.0
# -111,       0/    3028=0.0
# -112,       0/    2975=0.0
# -113,       0/    2925=0.0
# -114,       0/    2881=0.0
# -115,       0/    2837=0.0
# -116,       0/    2792=0.0
# -117,       0/    2753=0.0
# -118,       0/    2715=0.0
# -119,       0/    2674=0.0
# -120,       0/    2628=0.0
# -121,       0/    2586=0.0
# -122,       0/    2545=0.0
# -123,       0/    2506=0.0
# -124,       0/    2469=0.0
# -125,       0/    2435=0.0
# -126,       0/    2399=0.0
# -127,       0/    2362=0.0
# -128,       0/    2324=0.0
# -129,       0/    2287=0.0
# -130,       0/    2251=0.0
# -131,       0/    2214=0.0
# -132,       0/    2182=0.0
# -133,       0/    2150=0.0
# -134,       0/    2118=0.0
# -135,       0/    2086=0.0
# -136,       0/    2054=0.0
# -137,       0/    2022=0.0
# -138,       0/    1989=0.0
# -139,       0/    1956=0.0
# -140,       0/    1924=0.0
# -141,       0/    1891=0.0
# -142,       0/    1859=0.0
# -143,       0/    1827=0.0
# -144,       0/    1795=0.0
# -145,       0/    1755=0.0
# -146,       0/    1712=0.0
# -147,       0/    1679=0.0
# -148,       0/    1646=0.0
# -149,       0/    1614=0.0
# -150,       0/    1580=0.0
# -151,       0/    1546=0.0
# -152,       0/    1512=0.0
# -153,       0/    1476=0.0
# -154,       0/    1440=0.0
# -155,       0/    1404=0.0
# -156,       0/    1368=0.0
# -157,       0/    1332=0.0
# -158,       0/    1297=0.0
# -159,       0/    1263=0.0
# -160,       0/    1229=0.0
# -161,       0/    1195=0.0
# -162,       0/    1161=0.0
# -163,       0/    1127=0.0
# -164,       0/    1093=0.0
# -165,       0/    1059=0.0
# -166,       0/    1025=0.0
# -167,       0/     991=0.0
# -168,       0/     957=0.0
# -169,       0/     923=0.0
# -170,       0/     891=0.0
# -171,       0/     859=0.0
# -172,       0/     827=0.0
# -173,       0/     795=0.0
# -174,       0/     763=0.0
# -175,       0/     731=0.0
# -176,       0/     699=0.0
# -177,       0/     667=0.0
# -178,       0/     635=0.0
# -179,       0/     603=0.0
# -180,       0/     571=0.0
# -181,       0/     539=0.0
# -182,       0/     508=0.0
# -183,       0/     477=0.0
# -184,       0/     446=0.0
# -185,       0/     415=0.0
# -186,       0/     384=0.0
# -187,       0/     353=0.0
# -188,       0/     324=0.0
# -189,       0/     296=0.0
# -190,       0/     271=0.0
# -191,       0/     246=0.0
# -192,       0/     224=0.0
# -193,       0/     203=0.0
# -194,       0/     182=0.0
# -195,       0/     163=0.0
# -196,       0/     146=0.0
# -197,       0/     130=0.0
# -198,       0/     114=0.0
# -199,       0/      99=0.0

# %%
cmt = torch.Tensor([
    [negative, false_positive],
    [false_negative, positive],
]).int()

##visulaize the confusion matrix
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix of valiation set', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
plot_confusion_matrix(cmt, ['false', 'true'])
# Out:
# Confusion matrix, without normalization
# tensor([[4237689,   91765],
#         [  97684,  390270]], dtype=torch.int32)
